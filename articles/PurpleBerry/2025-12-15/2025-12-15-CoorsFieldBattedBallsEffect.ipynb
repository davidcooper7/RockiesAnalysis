# %%
import os, time, itertools
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
import matplotlib.pyplot as plt
import multiprocessing as mp
from copy import deepcopy
from pybaseball import *
# Out:
# /home/dcooper/anaconda3/envs/rockies/lib/python3.13/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %% [markdown]
# ## Build expected outcomes tables at and not at Coor's Field

# %%
# Load/build database
if not os.path.exists('../data/2020-2025_allBattedBallData.csv'):
    dfs = []
    for year in range(2020, 2026):
        print(f"Pulling {year}...")
        try:
            df = statcast(
                start_dt=f"{year}-03-01",
                end_dt=f"{year}-10-01",
                verbose=False
            )
            # Keep only balls in play
            df = df[df['type'] == 'X']
            dfs.append(df)
            time.sleep(5)  # be nice to Savant
        except Exception as e:
            print(f"Failed for {year}: {e}")
    
    all_bb_data = pd.concat(dfs, ignore_index=True)
    all_bb_data.to_csv('../data/2020-2025_allBattedBallData.csv')
else:
    all_bb_data = pd.read_csv('../data/2020-2025_allBattedBallData.csv', index_col=0)

# Filter to regular season games
all_bb_data = all_bb_data.loc[all_bb_data['game_type'] == 'R']

# Display dataframe
print(all_bb_data.shape)
all_bb_data.head()
# Out:
# (658753, 118)
#     pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 773         FF  2020-09-27           91.6           2.31           6.19
# 774         FF  2020-09-27           92.8           2.39           6.27
# 775         SI  2020-09-27           96.7          -2.20           5.92
# 776         SI  2020-09-27           98.0          -2.19           5.94
# 777         FF  2020-09-27           91.3           2.59           5.99
#
#           player_name  batter  pitcher     events    description  ...  \
# 773        Hand, Brad  605137   543272  field_out  hit_into_play  ...
# 774        Hand, Brad  663647   543272  field_out  hit_into_play  ...
# 775  Cederlind, Blake  596019   664977  field_out  hit_into_play  ...
# 776  Cederlind, Blake  640458   664977  field_out  hit_into_play  ...
# 777        Hand, Brad  624428   543272  field_out  hit_into_play  ...
#
#      batter_days_until_next_game  api_break_z_with_gravity  api_break_x_arm  \
# 773                          NaN                      1.38             0.86
# 774                          NaN                      1.25             0.92
# 775                          2.0                      1.92             1.44
# 776                          3.0                      1.82             1.38
# 777                          NaN                      1.37             1.09
#
#      api_break_x_batter_in  arm_angle attack_angle attack_direction  \
# 773                  -0.86       35.1          NaN              NaN
# 774                  -0.92       36.2          NaN              NaN
# 775                  -1.44       35.1          NaN              NaN
# 776                   1.38       34.1          NaN              NaN
# 777                   1.09       27.2          NaN              NaN
#
#     swing_path_tilt intercept_ball_minus_batter_pos_x_inches  \
# 773             NaN                                      NaN
# 774             NaN                                      NaN
# 775             NaN                                      NaN
# 776             NaN                                      NaN
# 777             NaN                                      NaN
#
#     intercept_ball_minus_batter_pos_y_inches
# 773                                      NaN
# 774                                      NaN
# 775                                      NaN
# 776                                      NaN
# 777                                      NaN
#
# [5 rows x 118 columns]

# %%
# Set bins
ev_labels = np.array(['<80', '80-85', '85-90', '90-95', '95-100', '100-105', '105-110', '>=110'])
ev_bins = np.array([0,80,85,90,95,100,105,110,999])
la_labels = np.array(['<10°', '10-25°', '25-35°', '35-50°', '>=50°'])
la_bins = np.array([-999, 10, 25, 35, 50, 999])
sa_labels = np.array(['-45 to -27°', '-27 to -9°', '-9 to 9°', '9 to 27°', '27 to 45°'])
sa_bins = np.array([-999, -27,  -9,  9,  27, 999])

# Add spray angle column
all_bb_data.insert(0, 'spray_angle', value=np.degrees(np.arctan2(all_bb_data['hc_x'] - 125, 199 - all_bb_data['hc_y'])), allow_duplicates=False)

# Add bin columns 
all_bb_data.insert(0, 'launch_speed_bin', value='', allow_duplicates=False)
all_bb_data.insert(0, 'launch_angle_bin', value='', allow_duplicates=False)
all_bb_data.insert(0, 'spray_angle_bin', value='', allow_duplicates=False)

# Reorder columns
tgt_cols = ['launch_speed', 'launch_speed_bin', 'launch_angle', 'launch_angle_bin', 'spray_angle', 'spray_angle_bin', 'events', 'home_team', 'hc_x', 'hc_y', 'stand'] 
df = all_bb_data[tgt_cols]

# Add data to new columns
df.loc[:,'launch_speed_bin'] = pd.cut(df['launch_speed'], ev_bins, labels=ev_labels, right=False)
df.loc[:,'launch_angle_bin'] = pd.cut(df['launch_angle'], la_bins, labels=la_labels, right=False)
df.loc[:,'spray_angle_bin'] = pd.cut(df['spray_angle'], sa_bins, labels=sa_labels, right=False)

df.head()
# Out:
#      launch_speed launch_speed_bin  launch_angle launch_angle_bin  \
# 773          88.4            85-90          32.0           25-35°
# 774         102.0          100-105          41.0           35-50°
# 775         100.5          100-105         -20.0             <10°
# 776          84.1            80-85          22.0           10-25°
# 777          88.7            85-90          17.0           10-25°
#
#      spray_angle spray_angle_bin     events home_team    hc_x    hc_y stand
# 773    43.763679       27 to 45°  field_out       CLE  217.94  101.96     R
# 774    -5.926369        -9 to 9°  field_out       CLE  108.85   43.42     R
# 775    24.128726        9 to 27°  field_out       CLE  152.61  137.36     L
# 776   -19.733931      -27 to -9°  field_out       CLE   81.95   78.99     R
# 777   -26.614826      -27 to -9°  field_out       CLE   76.57  102.35     L

# %%
# Build expected outcomes table
exp_outcomes = pd.DataFrame(columns=['EV', 'LA', 'SA', 'ΔHR', 'Δ3B', 'Δ2B', 'Δ1B', 'ΔOut', 'Bases_nCoors', 'Bases_Coors', 'n_Coors'])

# Check for valid events
valid_events = [
    'home_run', 'triple', 'double', 'single',
    'field_out', 'sac_fly', 'force_out',
    'double_play', 'grounded_into_double_play',
    'fielders_choice_out', 'fielders_choice',
    'triple_play', 'sac_fly_double_play'
]
df = df.loc[df['events'].isin(valid_events)]

# Iterate through bin type combinations
for ev_bin, la_bin, sa_bin in itertools.product(ev_labels, la_labels, sa_labels):

    # Filter by bin types
    bin_df = df.loc[df['launch_speed_bin'] == ev_bin]
    bin_df = bin_df.loc[bin_df['launch_angle_bin'] == la_bin]
    bin_df = bin_df.loc[bin_df['spray_angle_bin'] == sa_bin]

    # Split by location
    c_bin_df = bin_df.loc[bin_df['home_team'] == 'COL']
    nc_bin_df = bin_df.loc[bin_df['home_team'] != 'COL']

    # Iterate through outcomes and compute deltas for hits
    nc = []
    c = []
    deltas = []
    for event in ['home_run', 'triple', 'double', 'single', 'out']:

        # Get event occurance
        if event == 'out':
            nc_n_event = nc_bin_df.loc[nc_bin_df['events'].isin(['field_out', 'sac_fly', 'force_out', 'double_play', 'grounded_into_double_play', 'fielders_choice_out', 'fielders_choice', 'triple_play', 'sac_fly_double_play'])].shape[0]
            c_n_event = c_bin_df.loc[c_bin_df['events'].isin(['field_out', 'sac_fly', 'force_out', 'double_play', 'grounded_into_double_play', 'fielders_choice_out', 'fielders_choice', 'triple_play', 'sac_fly_double_play'])].shape[0]
        else:
            nc_n_event = nc_bin_df.loc[nc_bin_df['events'] == event].shape[0]
            c_n_event = c_bin_df.loc[c_bin_df['events'] == event].shape[0]

        # Convert to probabilities
        try:
            nc_p_event = nc_n_event / nc_bin_df.shape[0]
            c_p_event = c_n_event / c_bin_df.shape[0]
        except ZeroDivisionError:
            deltas.append(np.nan)
            nc.append(np.nan)
            c.append(np.nan)
            continue

        # Compute delta probabilities
        d_p_event = c_p_event - nc_p_event
        deltas.append(d_p_event)
        nc.append(nc_p_event)
        c.append(c_p_event)

    nc_bases = 4 * nc[0] + 3 * nc[1] + 2 * nc[2] + nc[1]
    c_bases = 4 * c[0] + 3 * c[1] + 2 * c[2] + c[1]
    exp_outcomes.loc[exp_outcomes.shape[0]] = [ev_bin, la_bin, sa_bin]  + deltas + [nc_bases, c_bases] + [c_bin_df.shape[0]]

# Drop NA
exp_outcomes.dropna(inplace=True)

# Drop anywhere n_Coors < 50
exp_outcomes = exp_outcomes.loc[exp_outcomes['n_Coors'] >= 50]

# Add delta bases
d_bases = 4 * exp_outcomes['ΔHR'] + 3 * exp_outcomes['Δ3B'] + 2 * exp_outcomes['Δ2B'] + exp_outcomes['Δ1B']
exp_outcomes.insert(10, 'ΔBases', d_bases)

# Round 
exp_outcomes = exp_outcomes.round(2)

# %% [markdown]
# ## Visualize dataframes

# %%
# Method for visualizaed dataframes
def plot_df(df, title, nrows=10, ascending=False):
    styled_df = df.sort_values(title, ascending=ascending).head(nrows)
    styled_df = styled_df.style.background_gradient(
        cmap='bwr', 
        vmin=-1, 
        vmax=1, 
        subset=['ΔHR', 'Δ3B', 'Δ2B', 'Δ1B', 'ΔOut', 'ΔBases']
    ).background_gradient(
        cmap='bwr', 
        vmin=0, 
        vmax=4, 
        subset=['Bases_nCoors', 'Bases_Coors']
    ).set_caption(title)

    display(styled_df)

# Sort by delta home runs
plot_df(exp_outcomes, 'ΔBases')
plot_df(exp_outcomes, 'Bases_nCoors')
plot_df(exp_outcomes, 'Bases_Coors')
plot_df(exp_outcomes, 'ΔHR')
plot_df(exp_outcomes, 'Δ3B')
plot_df(exp_outcomes, 'Δ2B')
plot_df(exp_outcomes, 'Δ1B')
plot_df(exp_outcomes, 'ΔOut')
plot_df(exp_outcomes, 'ΔOut', ascending=True)
# Out:
# <style type="text/css">
# #T_fea3e_row0_col3, #T_fea3e_row9_col10 {
#   background-color: #ffb4b4;
#   color: #000000;
# }
# #T_fea3e_row0_col4, #T_fea3e_row0_col6, #T_fea3e_row1_col4, #T_fea3e_row3_col6, #T_fea3e_row3_col9, #T_fea3e_row4_col6, #T_fea3e_row5_col4, #T_fea3e_row5_col6, #T_fea3e_row6_col4, #T_fea3e_row6_col6, #T_fea3e_row8_col6 {
#   background-color: #fffefe;
#   color: #000000;
# }
# #T_fea3e_row0_col5 {
#   background-color: #f8f8ff;
#   color: #000000;
# }
# #T_fea3e_row0_col7 {
#   background-color: #c0c0ff;
#   color: #000000;
# }
# #T_fea3e_row0_col8 {
#   background-color: #7070ff;
#   color: #f1f1f1;
# }
# #T_fea3e_row0_col9, #T_fea3e_row1_col5, #T_fea3e_row8_col5, #T_fea3e_row9_col3 {
#   background-color: #fafaff;
#   color: #000000;
# }
# #T_fea3e_row0_col10 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_fea3e_row1_col3, #T_fea3e_row4_col8 {
#   background-color: #ffbcbc;
#   color: #000000;
# }
# #T_fea3e_row1_col6, #T_fea3e_row2_col6, #T_fea3e_row7_col6 {
#   background-color: #fcfcff;
#   color: #000000;
# }
# #T_fea3e_row1_col7 {
#   background-color: #c4c4ff;
#   color: #000000;
# }
# #T_fea3e_row1_col8, #T_fea3e_row9_col6 {
#   background-color: #fffcfc;
#   color: #000000;
# }
# #T_fea3e_row1_col9, #T_fea3e_row5_col10 {
#   background-color: #ff7c7c;
#   color: #f1f1f1;
# }
# #T_fea3e_row1_col10 {
#   background-color: #ff0202;
#   color: #f1f1f1;
# }
# #T_fea3e_row2_col3, #T_fea3e_row3_col5, #T_fea3e_row4_col5, #T_fea3e_row8_col3 {
#   background-color: #fff0f0;
#   color: #000000;
# }
# #T_fea3e_row2_col4, #T_fea3e_row3_col4, #T_fea3e_row4_col4, #T_fea3e_row9_col4 {
#   background-color: #fff8f8;
#   color: #000000;
# }
# #T_fea3e_row2_col5 {
#   background-color: #ffc6c6;
#   color: #000000;
# }
# #T_fea3e_row2_col7 {
#   background-color: #b0b0ff;
#   color: #000000;
# }
# #T_fea3e_row2_col8 {
#   background-color: #6262ff;
#   color: #f1f1f1;
# }
# #T_fea3e_row2_col9, #T_fea3e_row4_col7 {
#   background-color: #cacaff;
#   color: #000000;
# }
# #T_fea3e_row2_col10 {
#   background-color: #ff3a3a;
#   color: #f1f1f1;
# }
# #T_fea3e_row3_col3 {
#   background-color: #ffdede;
#   color: #000000;
# }
# #T_fea3e_row3_col7 {
#   background-color: #c6c6ff;
#   color: #000000;
# }
# #T_fea3e_row3_col8 {
#   background-color: #9c9cff;
#   color: #f1f1f1;
# }
# #T_fea3e_row3_col10 {
#   background-color: #ff4242;
#   color: #f1f1f1;
# }
# #T_fea3e_row4_col3, #T_fea3e_row5_col3 {
#   background-color: #ffe0e0;
#   color: #000000;
# }
# #T_fea3e_row4_col9 {
#   background-color: #ff6262;
#   color: #f1f1f1;
# }
# #T_fea3e_row4_col10 {
#   background-color: #ff5454;
#   color: #f1f1f1;
# }
# #T_fea3e_row5_col5 {
#   background-color: #fffafa;
#   color: #000000;
# }
# #T_fea3e_row5_col7 {
#   background-color: #dedeff;
#   color: #000000;
# }
# #T_fea3e_row5_col8 {
#   background-color: #ff6c6c;
#   color: #f1f1f1;
# }
# #T_fea3e_row5_col9 {
#   background-color: #ff2a2a;
#   color: #f1f1f1;
# }
# #T_fea3e_row6_col3 {
#   background-color: #ffe8e8;
#   color: #000000;
# }
# #T_fea3e_row6_col5 {
#   background-color: #fff4f4;
#   color: #000000;
# }
# #T_fea3e_row6_col7 {
#   background-color: #e0e0ff;
#   color: #000000;
# }
# #T_fea3e_row6_col8 {
#   background-color: #6868ff;
#   color: #f1f1f1;
# }
# #T_fea3e_row6_col9, #T_fea3e_row8_col9 {
#   background-color: #a0a0ff;
#   color: #f1f1f1;
# }
# #T_fea3e_row6_col10 {
#   background-color: #ff9090;
#   color: #000000;
# }
# #T_fea3e_row7_col3 {
#   background-color: #f4f4ff;
#   color: #000000;
# }
# #T_fea3e_row7_col4 {
#   background-color: #ffeaea;
#   color: #000000;
# }
# #T_fea3e_row7_col5 {
#   background-color: #ffd0d0;
#   color: #000000;
# }
# #T_fea3e_row7_col7 {
#   background-color: #ccccff;
#   color: #000000;
# }
# #T_fea3e_row7_col8 {
#   background-color: #eaeaff;
#   color: #000000;
# }
# #T_fea3e_row7_col9 {
#   background-color: #ffd4d4;
#   color: #000000;
# }
# #T_fea3e_row7_col10 {
#   background-color: #ff9898;
#   color: #000000;
# }
# #T_fea3e_row8_col4 {
#   background-color: #ffeeee;
#   color: #000000;
# }
# #T_fea3e_row8_col7 {
#   background-color: #e6e6ff;
#   color: #000000;
# }
# #T_fea3e_row8_col8 {
#   background-color: #6464ff;
#   color: #f1f1f1;
# }
# #T_fea3e_row8_col10 {
#   background-color: #ff9c9c;
#   color: #000000;
# }
# #T_fea3e_row9_col5 {
#   background-color: #ffdcdc;
#   color: #000000;
# }
# #T_fea3e_row9_col7 {
#   background-color: #d6d6ff;
#   color: #000000;
# }
# #T_fea3e_row9_col8 {
#   background-color: #4646ff;
#   color: #f1f1f1;
# }
# #T_fea3e_row9_col9 {
#   background-color: #6e6eff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fea3e">
#   <caption>ΔBases</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fea3e_level0_col0" class="col_heading level0 col0" >EV</th>
#       <th id="T_fea3e_level0_col1" class="col_heading level0 col1" >LA</th>
#       <th id="T_fea3e_level0_col2" class="col_heading level0 col2" >SA</th>
#       <th id="T_fea3e_level0_col3" class="col_heading level0 col3" >ΔHR</th>
#       <th id="T_fea3e_level0_col4" class="col_heading level0 col4" >Δ3B</th>
#       <th id="T_fea3e_level0_col5" class="col_heading level0 col5" >Δ2B</th>
#       <th id="T_fea3e_level0_col6" class="col_heading level0 col6" >Δ1B</th>
#       <th id="T_fea3e_level0_col7" class="col_heading level0 col7" >ΔOut</th>
#       <th id="T_fea3e_level0_col8" class="col_heading level0 col8" >Bases_nCoors</th>
#       <th id="T_fea3e_level0_col9" class="col_heading level0 col9" >Bases_Coors</th>
#       <th id="T_fea3e_level0_col10" class="col_heading level0 col10" >ΔBases</th>
#       <th id="T_fea3e_level0_col11" class="col_heading level0 col11" >n_Coors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fea3e_level0_row0" class="row_heading level0 row0" >115</th>
#       <td id="T_fea3e_row0_col0" class="data row0 col0" >95-100</td>
#       <td id="T_fea3e_row0_col1" class="data row0 col1" >35-50°</td>
#       <td id="T_fea3e_row0_col2" class="data row0 col2" >-45 to -27°</td>
#       <td id="T_fea3e_row0_col3" class="data row0 col3" >0.290000</td>
#       <td id="T_fea3e_row0_col4" class="data row0 col4" >-0.000000</td>
#       <td id="T_fea3e_row0_col5" class="data row0 col5" >-0.030000</td>
#       <td id="T_fea3e_row0_col6" class="data row0 col6" >-0.000000</td>
#       <td id="T_fea3e_row0_col7" class="data row0 col7" >-0.250000</td>
#       <td id="T_fea3e_row0_col8" class="data row0 col8" >0.890000</td>
#       <td id="T_fea3e_row0_col9" class="data row0 col9" >1.960000</td>
#       <td id="T_fea3e_row0_col10" class="data row0 col10" >1.070000</td>
#       <td id="T_fea3e_row0_col11" class="data row0 col11" >57</td>
#     </tr>
#     <tr>
#       <th id="T_fea3e_level0_row1" class="row_heading level0 row1" >110</th>
#       <td id="T_fea3e_row1_col0" class="data row1 col0" >95-100</td>
#       <td id="T_fea3e_row1_col1" class="data row1 col1" >25-35°</td>
#       <td id="T_fea3e_row1_col2" class="data row1 col2" >-45 to -27°</td>
#       <td id="T_fea3e_row1_col3" class="data row1 col3" >0.260000</td>
#       <td id="T_fea3e_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_fea3e_row1_col5" class="data row1 col5" >-0.020000</td>
#       <td id="T_fea3e_row1_col6" class="data row1 col6" >-0.010000</td>
#       <td id="T_fea3e_row1_col7" class="data row1 col7" >-0.230000</td>
#       <td id="T_fea3e_row1_col8" class="data row1 col8" >2.030000</td>
#       <td id="T_fea3e_row1_col9" class="data row1 col9" >3.030000</td>
#       <td id="T_fea3e_row1_col10" class="data row1 col10" >0.990000</td>
#       <td id="T_fea3e_row1_col11" class="data row1 col11" >103</td>
#     </tr>
#     <tr>
#       <th id="T_fea3e_level0_row2" class="row_heading level0 row2" >113</th>
#       <td id="T_fea3e_row2_col0" class="data row2 col0" >95-100</td>
#       <td id="T_fea3e_row2_col1" class="data row2 col1" >25-35°</td>
#       <td id="T_fea3e_row2_col2" class="data row2 col2" >9 to 27°</td>
#       <td id="T_fea3e_row2_col3" class="data row2 col3" >0.060000</td>
#       <td id="T_fea3e_row2_col4" class="data row2 col4" >0.030000</td>
#       <td id="T_fea3e_row2_col5" class="data row2 col5" >0.220000</td>
#       <td id="T_fea3e_row2_col6" class="data row2 col6" >-0.010000</td>
#       <td id="T_fea3e_row2_col7" class="data row2 col7" >-0.310000</td>
#       <td id="T_fea3e_row2_col8" class="data row2 col8" >0.770000</td>
#       <td id="T_fea3e_row2_col9" class="dat
# <style type="text/css">
# #T_aea58_row0_col3, #T_aea58_row0_col10, #T_aea58_row9_col3 {
#   background-color: #f0f0ff;
#   color: #000000;
# }
# #T_aea58_row0_col4, #T_aea58_row2_col4, #T_aea58_row2_col5, #T_aea58_row3_col5, #T_aea58_row8_col3 {
#   background-color: #fffafa;
#   color: #000000;
# }
# #T_aea58_row0_col5 {
#   background-color: #fff2f2;
#   color: #000000;
# }
# #T_aea58_row0_col6, #T_aea58_row1_col6, #T_aea58_row3_col4, #T_aea58_row3_col6, #T_aea58_row4_col6, #T_aea58_row5_col6, #T_aea58_row6_col4, #T_aea58_row8_col4 {
#   background-color: #fffefe;
#   color: #000000;
# }
# #T_aea58_row0_col7, #T_aea58_row6_col5, #T_aea58_row8_col7, #T_aea58_row9_col6 {
#   background-color: #fafaff;
#   color: #000000;
# }
# #T_aea58_row0_col8 {
#   background-color: #ff1616;
#   color: #f1f1f1;
# }
# #T_aea58_row0_col9 {
#   background-color: #ff1c1c;
#   color: #f1f1f1;
# }
# #T_aea58_row1_col3 {
#   background-color: #ffe8e8;
#   color: #000000;
# }
# #T_aea58_row1_col4, #T_aea58_row6_col8 {
#   background-color: #fffcfc;
#   color: #000000;
# }
# #T_aea58_row1_col5, #T_aea58_row1_col7 {
#   background-color: #f2f2ff;
#   color: #000000;
# }
# #T_aea58_row1_col8 {
#   background-color: #ff2e2e;
#   color: #f1f1f1;
# }
# #T_aea58_row1_col9 {
#   background-color: #ff0606;
#   color: #f1f1f1;
# }
# #T_aea58_row1_col10 {
#   background-color: #ffb4b4;
#   color: #000000;
# }
# #T_aea58_row2_col3, #T_aea58_row4_col4, #T_aea58_row8_col6, #T_aea58_row9_col10 {
#   background-color: #fff4f4;
#   color: #000000;
# }
# #T_aea58_row2_col6, #T_aea58_row6_col6, #T_aea58_row7_col6 {
#   background-color: #fcfcff;
#   color: #000000;
# }
# #T_aea58_row2_col7 {
#   background-color: #eeeeff;
#   color: #000000;
# }
# #T_aea58_row2_col8 {
#   background-color: #ff3e3e;
#   color: #f1f1f1;
# }
# #T_aea58_row2_col9 {
#   background-color: #ff1a1a;
#   color: #f1f1f1;
# }
# #T_aea58_row2_col10, #T_aea58_row5_col8, #T_aea58_row6_col3 {
#   background-color: #ffbcbc;
#   color: #000000;
# }
# #T_aea58_row3_col3, #T_aea58_row5_col3 {
#   background-color: #ffe0e0;
#   color: #000000;
# }
# #T_aea58_row3_col7, #T_aea58_row9_col9 {
#   background-color: #dedeff;
#   color: #000000;
# }
# #T_aea58_row3_col8 {
#   background-color: #ff6c6c;
#   color: #f1f1f1;
# }
# #T_aea58_row3_col9 {
#   background-color: #ff2a2a;
#   color: #f1f1f1;
# }
# #T_aea58_row3_col10, #T_aea58_row6_col9 {
#   background-color: #ff7c7c;
#   color: #f1f1f1;
# }
# #T_aea58_row4_col3, #T_aea58_row7_col3, #T_aea58_row9_col7 {
#   background-color: #f4f4ff;
#   color: #000000;
# }
# #T_aea58_row4_col5 {
#   background-color: #ffdede;
#   color: #000000;
# }
# #T_aea58_row4_col7 {
#   background-color: #e0e0ff;
#   color: #000000;
# }
# #T_aea58_row4_col8, #T_aea58_row7_col10 {
#   background-color: #ff9898;
#   color: #000000;
# }
# #T_aea58_row4_col9 {
#   background-color: #ff7a7a;
#   color: #f1f1f1;
# }
# #T_aea58_row4_col10 {
#   background-color: #ffcece;
#   color: #000000;
# }
# #T_aea58_row5_col4, #T_aea58_row8_col10 {
#   background-color: #fff8f8;
#   color: #000000;
# }
# #T_aea58_row5_col5, #T_aea58_row9_col4, #T_aea58_row9_col5 {
#   background-color: #fff0f0;
#   color: #000000;
# }
# #T_aea58_row5_col7 {
#   background-color: #cacaff;
#   color: #000000;
# }
# #T_aea58_row5_col9 {
#   background-color: #ff6262;
#   color: #f1f1f1;
# }
# #T_aea58_row5_col10 {
#   background-color: #ff5454;
#   color: #f1f1f1;
# }
# #T_aea58_row6_col7 {
#   background-color: #c4c4ff;
#   color: #000000;
# }
# #T_aea58_row6_col10 {
#   background-color: #ff0202;
#   color: #f1f1f1;
# }
# #T_aea58_row7_col4 {
#   background-color: #ffeaea;
#   color: #000000;
# }
# #T_aea58_row7_col5 {
#   background-color: #ffd0d0;
#   color: #000000;
# }
# #T_aea58_row7_col7 {
#   background-color: #ccccff;
#   color: #000000;
# }
# #T_aea58_row7_col8 {
#   background-color: #eaeaff;
#   color: #000000;
# }
# #T_aea58_row7_col9 {
#   background-color: #ffd4d4;
#   color: #000000;
# }
# #T_aea58_row8_col5 {
#   background-color: #f8f8ff;
#   color: #000000;
# }
# #T_aea58_row8_col8 {
#   background-color: #d2d2ff;
#   color: #000000;
# }
# #T_aea58_row8_col9 {
#   background-color: #d0d0ff;
#   color: #000000;
# }
# #T_aea58_row9_col8 {
#   background-color: #ceceff;
#   color: #000000;
# }
# </style>
# <table id="T_aea58">
#   <caption>Bases_nCoors</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aea58_level0_col0" class="col_heading level0 col0" >EV</th>
#       <th id="T_aea58_level0_col1" class="col_heading level0 col1" >LA</th>
#       <th id="T_aea58_level0_col2" class="col_heading level0 col2" >SA</th>
#       <th id="T_aea58_level0_col3" class="col_heading level0 col3" >ΔHR</th>
#       <th id="T_aea58_level0_col4" class="col_heading level0 col4" >Δ3B</th>
#       <th id="T_aea58_level0_col5" class="col_heading level0 col5" >Δ2B</th>
#       <th id="T_aea58_level0_col6" class="col_heading level0 col6" >Δ1B</th>
#       <th id="T_aea58_level0_col7" class="col_heading level0 col7" >ΔOut</th>
#       <th id="T_aea58_level0_col8" class="col_heading level0 col8" >Bases_nCoors</th>
#       <th id="T_aea58_level0_col9" class="col_heading level0 col9" >Bases_Coors</th>
#       <th id="T_aea58_level0_col10" class="col_heading level0 col10" >ΔBases</th>
#       <th id="T_aea58_level0_col11" class="col_heading level0 col11" >n_Coors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aea58_level0_row0" class="row_heading level0 row0" >161</th>
#       <td id="T_aea58_row0_col0" class="data row0 col0" >105-110</td>
#       <td id="T_aea58_row0_col1" class="data row0 col1" >25-35°</td>
#       <td id="T_aea58_row0_col2" class="data row0 col2" >-27 to -9°</td>
#       <td id="T_aea58_row0_col3" class="data row0 col3" >-0.060000</td>
#       <td id="T_aea58_row0_col4" class="data row0 col4" >0.020000</td>
#       <td id="T_aea58_row0_col5" class="data row0 col5" >0.050000</td>
#       <td id="T_aea58_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_aea58_row0_col7" class="data row0 col7" >-0.020000</td>
#       <td id="T_aea58_row0_col8" class="data row0 col8" >3.820000</td>
#       <td id="T_aea58_row0_col9" class="data row0 col9" >3.780000</td>
#       <td id="T_aea58_row0_col10" class="data row0 col10" >-0.060000</td>
#       <td id="T_aea58_row0_col11" class="data row0 col11" >54</td>
#     </tr>
#     <tr>
#       <th id="T_aea58_level0_row1" class="row_heading level0 row1" >135</th>
#       <td id="T_aea58_row1_col0" class="data row1 col0" >100-105</td>
#       <td id="T_aea58_row1_col1" class="data row1 col1" >25-35°</td>
#       <td id="T_aea58_row1_col2" class="data row1 col2" >-45 to -27°</td>
#       <td id="T_aea58_row1_col3" class="data row1 col3" >0.090000</td>
#       <td id="T_aea58_row1_col4" class="data row1 col4" >0.010000</td>
#       <td id="T_aea58_row1_col5" class="data row1 col5" >-0.050000</td>
#       <td id="T_aea58_row1_col6" class="data row1 col6" >-0.000000</td>
#       <td id="T_aea58_row1_col7" class="data row1 col7" >-0.050000</td>
#       <td id="T_aea58_row1_col8" class="data row1 col8" >3.640000</td>
#       <td id="T_aea58_row1_col9" class="data row1 col9" >3.950000</td>
#       <td id="T_aea58_row1_col10" class="data row1 col10" >0.290000</td>
#       <td id="T_aea58_row1_col11" class="data row1 col11" >75</td>
#     </tr>
#     <tr>
#       <th id="T_aea58_level0_row2" class="row_heading level0 row2" >139</th>
#       <td id="T_aea58_row2_col0" class="data row2 col0" >100-105</td>
#       <td id="T_aea58_row2_col1" class="data row2 col1" >25-35°</td>
#       <td id="T_aea58_row2_col2" class="data row2 col2" >27 to 45°</td>
#       <td id="T_aea58_row2_col3" class="data row2 col3" >0.040000</td>
#       <td id="T_aea58_row2_col4" class="data row2 col4" >0.020000</td>
#       <td id="T_aea58_row2_col5" class="data row2 col5" >0.020000</td>
#       <td id="T_aea58_row2_col6" class="data row2 col6" >-0.010000</td>
#       <td id="T_aea58_row2_col7" class="data row2 col7" >-0.070000</td>
#       <td id="T_aea58_row2_col8" class="data row2 col8" >3.500000</td>
#       <td id="T_aea58_row2_col9" class="data row2 col9" >3.790000</td>
#       <td id="T_aea58_row2_col10" class="data row2 col10" >0.260000</td>
#       <td id="T_aea58_row2_col11" class="data row2 col11" >66</td>
#     </tr>
#     <tr>
#       <th id="T_aea58_level0_row3" class="row_heading level0 row3" >162</th>
#       <td id="T_aea58_row3_co
# <style type="text/css">
# #T_c10c9_row0_col3 {
#   background-color: #ffe8e8;
#   color: #000000;
# }
# #T_c10c9_row0_col4, #T_c10c9_row6_col8 {
#   background-color: #fffcfc;
#   color: #000000;
# }
# #T_c10c9_row0_col5, #T_c10c9_row0_col7 {
#   background-color: #f2f2ff;
#   color: #000000;
# }
# #T_c10c9_row0_col6, #T_c10c9_row2_col6, #T_c10c9_row3_col4, #T_c10c9_row3_col6, #T_c10c9_row4_col6, #T_c10c9_row5_col6, #T_c10c9_row6_col4, #T_c10c9_row8_col6, #T_c10c9_row8_col9, #T_c10c9_row9_col4, #T_c10c9_row9_col6 {
#   background-color: #fffefe;
#   color: #000000;
# }
# #T_c10c9_row0_col8 {
#   background-color: #ff2e2e;
#   color: #f1f1f1;
# }
# #T_c10c9_row0_col9 {
#   background-color: #ff0606;
#   color: #f1f1f1;
# }
# #T_c10c9_row0_col10, #T_c10c9_row9_col3 {
#   background-color: #ffb4b4;
#   color: #000000;
# }
# #T_c10c9_row1_col3, #T_c10c9_row5_col4 {
#   background-color: #fff4f4;
#   color: #000000;
# }
# #T_c10c9_row1_col4, #T_c10c9_row1_col5, #T_c10c9_row2_col4, #T_c10c9_row3_col5 {
#   background-color: #fffafa;
#   color: #000000;
# }
# #T_c10c9_row1_col6, #T_c10c9_row6_col6, #T_c10c9_row7_col6 {
#   background-color: #fcfcff;
#   color: #000000;
# }
# #T_c10c9_row1_col7 {
#   background-color: #eeeeff;
#   color: #000000;
# }
# #T_c10c9_row1_col8 {
#   background-color: #ff3e3e;
#   color: #f1f1f1;
# }
# #T_c10c9_row1_col9 {
#   background-color: #ff1a1a;
#   color: #f1f1f1;
# }
# #T_c10c9_row1_col10, #T_c10c9_row4_col8, #T_c10c9_row6_col3 {
#   background-color: #ffbcbc;
#   color: #000000;
# }
# #T_c10c9_row2_col3, #T_c10c9_row2_col10 {
#   background-color: #f0f0ff;
#   color: #000000;
# }
# #T_c10c9_row2_col5 {
#   background-color: #fff2f2;
#   color: #000000;
# }
# #T_c10c9_row2_col7, #T_c10c9_row6_col5, #T_c10c9_row9_col9 {
#   background-color: #fafaff;
#   color: #000000;
# }
# #T_c10c9_row2_col8 {
#   background-color: #ff1616;
#   color: #f1f1f1;
# }
# #T_c10c9_row2_col9 {
#   background-color: #ff1c1c;
#   color: #f1f1f1;
# }
# #T_c10c9_row3_col3, #T_c10c9_row4_col3 {
#   background-color: #ffe0e0;
#   color: #000000;
# }
# #T_c10c9_row3_col7 {
#   background-color: #dedeff;
#   color: #000000;
# }
# #T_c10c9_row3_col8 {
#   background-color: #ff6c6c;
#   color: #f1f1f1;
# }
# #T_c10c9_row3_col9 {
#   background-color: #ff2a2a;
#   color: #f1f1f1;
# }
# #T_c10c9_row3_col10, #T_c10c9_row6_col9 {
#   background-color: #ff7c7c;
#   color: #f1f1f1;
# }
# #T_c10c9_row4_col4, #T_c10c9_row8_col4 {
#   background-color: #fff8f8;
#   color: #000000;
# }
# #T_c10c9_row4_col5, #T_c10c9_row8_col5 {
#   background-color: #fff0f0;
#   color: #000000;
# }
# #T_c10c9_row4_col7 {
#   background-color: #cacaff;
#   color: #000000;
# }
# #T_c10c9_row4_col9 {
#   background-color: #ff6262;
#   color: #f1f1f1;
# }
# #T_c10c9_row4_col10 {
#   background-color: #ff5454;
#   color: #f1f1f1;
# }
# #T_c10c9_row5_col3, #T_c10c9_row7_col3 {
#   background-color: #f4f4ff;
#   color: #000000;
# }
# #T_c10c9_row5_col5, #T_c10c9_row8_col3 {
#   background-color: #ffdede;
#   color: #000000;
# }
# #T_c10c9_row5_col7 {
#   background-color: #e0e0ff;
#   color: #000000;
# }
# #T_c10c9_row5_col8, #T_c10c9_row7_col10 {
#   background-color: #ff9898;
#   color: #000000;
# }
# #T_c10c9_row5_col9 {
#   background-color: #ff7a7a;
#   color: #f1f1f1;
# }
# #T_c10c9_row5_col10 {
#   background-color: #ffcece;
#   color: #000000;
# }
# #T_c10c9_row6_col7 {
#   background-color: #c4c4ff;
#   color: #000000;
# }
# #T_c10c9_row6_col10 {
#   background-color: #ff0202;
#   color: #f1f1f1;
# }
# #T_c10c9_row7_col4 {
#   background-color: #ffeaea;
#   color: #000000;
# }
# #T_c10c9_row7_col5 {
#   background-color: #ffd0d0;
#   color: #000000;
# }
# #T_c10c9_row7_col7 {
#   background-color: #ccccff;
#   color: #000000;
# }
# #T_c10c9_row7_col8 {
#   background-color: #eaeaff;
#   color: #000000;
# }
# #T_c10c9_row7_col9 {
#   background-color: #ffd4d4;
#   color: #000000;
# }
# #T_c10c9_row8_col7 {
#   background-color: #c6c6ff;
#   color: #000000;
# }
# #T_c10c9_row8_col8 {
#   background-color: #9c9cff;
#   color: #f1f1f1;
# }
# #T_c10c9_row8_col10 {
#   background-color: #ff4242;
#   color: #f1f1f1;
# }
# #T_c10c9_row9_col5 {
#   background-color: #f8f8ff;
#   color: #000000;
# }
# #T_c10c9_row9_col7 {
#   background-color: #c0c0ff;
#   color: #000000;
# }
# #T_c10c9_row9_col8 {
#   background-color: #7070ff;
#   color: #f1f1f1;
# }
# #T_c10c9_row9_col10 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c10c9">
#   <caption>Bases_Coors</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c10c9_level0_col0" class="col_heading level0 col0" >EV</th>
#       <th id="T_c10c9_level0_col1" class="col_heading level0 col1" >LA</th>
#       <th id="T_c10c9_level0_col2" class="col_heading level0 col2" >SA</th>
#       <th id="T_c10c9_level0_col3" class="col_heading level0 col3" >ΔHR</th>
#       <th id="T_c10c9_level0_col4" class="col_heading level0 col4" >Δ3B</th>
#       <th id="T_c10c9_level0_col5" class="col_heading level0 col5" >Δ2B</th>
#       <th id="T_c10c9_level0_col6" class="col_heading level0 col6" >Δ1B</th>
#       <th id="T_c10c9_level0_col7" class="col_heading level0 col7" >ΔOut</th>
#       <th id="T_c10c9_level0_col8" class="col_heading level0 col8" >Bases_nCoors</th>
#       <th id="T_c10c9_level0_col9" class="col_heading level0 col9" >Bases_Coors</th>
#       <th id="T_c10c9_level0_col10" class="col_heading level0 col10" >ΔBases</th>
#       <th id="T_c10c9_level0_col11" class="col_heading level0 col11" >n_Coors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c10c9_level0_row0" class="row_heading level0 row0" >135</th>
#       <td id="T_c10c9_row0_col0" class="data row0 col0" >100-105</td>
#       <td id="T_c10c9_row0_col1" class="data row0 col1" >25-35°</td>
#       <td id="T_c10c9_row0_col2" class="data row0 col2" >-45 to -27°</td>
#       <td id="T_c10c9_row0_col3" class="data row0 col3" >0.090000</td>
#       <td id="T_c10c9_row0_col4" class="data row0 col4" >0.010000</td>
#       <td id="T_c10c9_row0_col5" class="data row0 col5" >-0.050000</td>
#       <td id="T_c10c9_row0_col6" class="data row0 col6" >-0.000000</td>
#       <td id="T_c10c9_row0_col7" class="data row0 col7" >-0.050000</td>
#       <td id="T_c10c9_row0_col8" class="data row0 col8" >3.640000</td>
#       <td id="T_c10c9_row0_col9" class="data row0 col9" >3.950000</td>
#       <td id="T_c10c9_row0_col10" class="data row0 col10" >0.290000</td>
#       <td id="T_c10c9_row0_col11" class="data row0 col11" >75</td>
#     </tr>
#     <tr>
#       <th id="T_c10c9_level0_row1" class="row_heading level0 row1" >139</th>
#       <td id="T_c10c9_row1_col0" class="data row1 col0" >100-105</td>
#       <td id="T_c10c9_row1_col1" class="data row1 col1" >25-35°</td>
#       <td id="T_c10c9_row1_col2" class="data row1 col2" >27 to 45°</td>
#       <td id="T_c10c9_row1_col3" class="data row1 col3" >0.040000</td>
#       <td id="T_c10c9_row1_col4" class="data row1 col4" >0.020000</td>
#       <td id="T_c10c9_row1_col5" class="data row1 col5" >0.020000</td>
#       <td id="T_c10c9_row1_col6" class="data row1 col6" >-0.010000</td>
#       <td id="T_c10c9_row1_col7" class="data row1 col7" >-0.070000</td>
#       <td id="T_c10c9_row1_col8" class="data row1 col8" >3.500000</td>
#       <td id="T_c10c9_row1_col9" class="data row1 col9" >3.790000</td>
#       <td id="T_c10c9_row1_col10" class="data row1 col10" >0.260000</td>
#       <td id="T_c10c9_row1_col11" class="data row1 col11" >66</td>
#     </tr>
#     <tr>
#       <th id="T_c10c9_level0_row2" class="row_heading level0 row2" >161</th>
#       <td id="T_c10c9_row2_col0" class="data row2 col0" >105-110</td>
#       <td id="T_c10c9_row2_col1" class="data row2 col1" >25-35°</td>
#       <td id="T_c10c9_row2_col2" class="data row2 col2" >-27 to -9°</td>
#       <td id="T_c10c9_row2_col3" class="data row2 col3" >-0.060000</td>
#       <td id="T_c10c9_row2_col4" class="data row2 col4" >0.020000</td>
#       <td id="T_c10c9_row2_col5" class="data row2 col5" >0.050000</td>
#       <td id="T_c10c9_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_c10c9_row2_col7" class="data row2 col7" >-0.020000</td>
#       <td id="T_c10c9_row2_col8" class="data row2 col8" >3.820000</td>
#       <td id="T_c10c9_row2_col9" class="data row2 col9" >3.780000</td>
#       <td id="T_c10c9_row2_col10" class="data row2 col10" >-0.060000</td>
#       <td id="T_c10c9_row2_col11" class="da
# <style type="text/css">
# #T_ce092_row0_col3, #T_ce092_row5_col10 {
#   background-color: #ffb4b4;
#   color: #000000;
# }
# #T_ce092_row0_col4, #T_ce092_row0_col6, #T_ce092_row1_col4, #T_ce092_row2_col6, #T_ce092_row2_col9, #T_ce092_row3_col6, #T_ce092_row4_col4, #T_ce092_row4_col6, #T_ce092_row5_col6, #T_ce092_row6_col4, #T_ce092_row6_col6, #T_ce092_row8_col6 {
#   background-color: #fffefe;
#   color: #000000;
# }
# #T_ce092_row0_col5 {
#   background-color: #f8f8ff;
#   color: #000000;
# }
# #T_ce092_row0_col7 {
#   background-color: #c0c0ff;
#   color: #000000;
# }
# #T_ce092_row0_col8 {
#   background-color: #7070ff;
#   color: #f1f1f1;
# }
# #T_ce092_row0_col9, #T_ce092_row1_col5, #T_ce092_row8_col5 {
#   background-color: #fafaff;
#   color: #000000;
# }
# #T_ce092_row0_col10 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_ce092_row1_col3, #T_ce092_row3_col8 {
#   background-color: #ffbcbc;
#   color: #000000;
# }
# #T_ce092_row1_col6, #T_ce092_row7_col4, #T_ce092_row7_col6, #T_ce092_row9_col6 {
#   background-color: #fcfcff;
#   color: #000000;
# }
# #T_ce092_row1_col7 {
#   background-color: #c4c4ff;
#   color: #000000;
# }
# #T_ce092_row1_col8, #T_ce092_row5_col4, #T_ce092_row7_col7 {
#   background-color: #fffcfc;
#   color: #000000;
# }
# #T_ce092_row1_col9, #T_ce092_row4_col10 {
#   background-color: #ff7c7c;
#   color: #f1f1f1;
# }
# #T_ce092_row1_col10 {
#   background-color: #ff0202;
#   color: #f1f1f1;
# }
# #T_ce092_row2_col3, #T_ce092_row7_col10 {
#   background-color: #ffdede;
#   color: #000000;
# }
# #T_ce092_row2_col4, #T_ce092_row3_col4, #T_ce092_row9_col4 {
#   background-color: #fff8f8;
#   color: #000000;
# }
# #T_ce092_row2_col5, #T_ce092_row3_col5, #T_ce092_row8_col3, #T_ce092_row9_col3 {
#   background-color: #fff0f0;
#   color: #000000;
# }
# #T_ce092_row2_col7 {
#   background-color: #c6c6ff;
#   color: #000000;
# }
# #T_ce092_row2_col8 {
#   background-color: #9c9cff;
#   color: #f1f1f1;
# }
# #T_ce092_row2_col10 {
#   background-color: #ff4242;
#   color: #f1f1f1;
# }
# #T_ce092_row3_col3, #T_ce092_row4_col3 {
#   background-color: #ffe0e0;
#   color: #000000;
# }
# #T_ce092_row3_col7, #T_ce092_row9_col9 {
#   background-color: #cacaff;
#   color: #000000;
# }
# #T_ce092_row3_col9 {
#   background-color: #ff6262;
#   color: #f1f1f1;
# }
# #T_ce092_row3_col10 {
#   background-color: #ff5454;
#   color: #f1f1f1;
# }
# #T_ce092_row4_col5 {
#   background-color: #fffafa;
#   color: #000000;
# }
# #T_ce092_row4_col7 {
#   background-color: #dedeff;
#   color: #000000;
# }
# #T_ce092_row4_col8 {
#   background-color: #ff6c6c;
#   color: #f1f1f1;
# }
# #T_ce092_row4_col9 {
#   background-color: #ff2a2a;
#   color: #f1f1f1;
# }
# #T_ce092_row5_col3, #T_ce092_row6_col3 {
#   background-color: #ffe8e8;
#   color: #000000;
# }
# #T_ce092_row5_col5, #T_ce092_row5_col7 {
#   background-color: #f2f2ff;
#   color: #000000;
# }
# #T_ce092_row5_col8 {
#   background-color: #ff2e2e;
#   color: #f1f1f1;
# }
# #T_ce092_row5_col9 {
#   background-color: #ff0606;
#   color: #f1f1f1;
# }
# #T_ce092_row6_col5 {
#   background-color: #fff4f4;
#   color: #000000;
# }
# #T_ce092_row6_col7 {
#   background-color: #e0e0ff;
#   color: #000000;
# }
# #T_ce092_row6_col8 {
#   background-color: #6868ff;
#   color: #f1f1f1;
# }
# #T_ce092_row6_col9, #T_ce092_row8_col9 {
#   background-color: #a0a0ff;
#   color: #f1f1f1;
# }
# #T_ce092_row6_col10 {
#   background-color: #ff9090;
#   color: #000000;
# }
# #T_ce092_row7_col3 {
#   background-color: #ffeaea;
#   color: #000000;
# }
# #T_ce092_row7_col5 {
#   background-color: #eaeaff;
#   color: #000000;
# }
# #T_ce092_row7_col8 {
#   background-color: #5050ff;
#   color: #f1f1f1;
# }
# #T_ce092_row7_col9, #T_ce092_row9_col8 {
#   background-color: #6262ff;
#   color: #f1f1f1;
# }
# #T_ce092_row8_col4 {
#   background-color: #ffeeee;
#   color: #000000;
# }
# #T_ce092_row8_col7 {
#   background-color: #e6e6ff;
#   color: #000000;
# }
# #T_ce092_row8_col8 {
#   background-color: #6464ff;
#   color: #f1f1f1;
# }
# #T_ce092_row8_col10 {
#   background-color: #ff9c9c;
#   color: #000000;
# }
# #T_ce092_row9_col5 {
#   background-color: #ffc6c6;
#   color: #000000;
# }
# #T_ce092_row9_col7 {
#   background-color: #b0b0ff;
#   color: #000000;
# }
# #T_ce092_row9_col10 {
#   background-color: #ff3a3a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ce092">
#   <caption>ΔHR</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce092_level0_col0" class="col_heading level0 col0" >EV</th>
#       <th id="T_ce092_level0_col1" class="col_heading level0 col1" >LA</th>
#       <th id="T_ce092_level0_col2" class="col_heading level0 col2" >SA</th>
#       <th id="T_ce092_level0_col3" class="col_heading level0 col3" >ΔHR</th>
#       <th id="T_ce092_level0_col4" class="col_heading level0 col4" >Δ3B</th>
#       <th id="T_ce092_level0_col5" class="col_heading level0 col5" >Δ2B</th>
#       <th id="T_ce092_level0_col6" class="col_heading level0 col6" >Δ1B</th>
#       <th id="T_ce092_level0_col7" class="col_heading level0 col7" >ΔOut</th>
#       <th id="T_ce092_level0_col8" class="col_heading level0 col8" >Bases_nCoors</th>
#       <th id="T_ce092_level0_col9" class="col_heading level0 col9" >Bases_Coors</th>
#       <th id="T_ce092_level0_col10" class="col_heading level0 col10" >ΔBases</th>
#       <th id="T_ce092_level0_col11" class="col_heading level0 col11" >n_Coors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce092_level0_row0" class="row_heading level0 row0" >115</th>
#       <td id="T_ce092_row0_col0" class="data row0 col0" >95-100</td>
#       <td id="T_ce092_row0_col1" class="data row0 col1" >35-50°</td>
#       <td id="T_ce092_row0_col2" class="data row0 col2" >-45 to -27°</td>
#       <td id="T_ce092_row0_col3" class="data row0 col3" >0.290000</td>
#       <td id="T_ce092_row0_col4" class="data row0 col4" >-0.000000</td>
#       <td id="T_ce092_row0_col5" class="data row0 col5" >-0.030000</td>
#       <td id="T_ce092_row0_col6" class="data row0 col6" >-0.000000</td>
#       <td id="T_ce092_row0_col7" class="data row0 col7" >-0.250000</td>
#       <td id="T_ce092_row0_col8" class="data row0 col8" >0.890000</td>
#       <td id="T_ce092_row0_col9" class="data row0 col9" >1.960000</td>
#       <td id="T_ce092_row0_col10" class="data row0 col10" >1.070000</td>
#       <td id="T_ce092_row0_col11" class="data row0 col11" >57</td>
#     </tr>
#     <tr>
#       <th id="T_ce092_level0_row1" class="row_heading level0 row1" >110</th>
#       <td id="T_ce092_row1_col0" class="data row1 col0" >95-100</td>
#       <td id="T_ce092_row1_col1" class="data row1 col1" >25-35°</td>
#       <td id="T_ce092_row1_col2" class="data row1 col2" >-45 to -27°</td>
#       <td id="T_ce092_row1_col3" class="data row1 col3" >0.260000</td>
#       <td id="T_ce092_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_ce092_row1_col5" class="data row1 col5" >-0.020000</td>
#       <td id="T_ce092_row1_col6" class="data row1 col6" >-0.010000</td>
#       <td id="T_ce092_row1_col7" class="data row1 col7" >-0.230000</td>
#       <td id="T_ce092_row1_col8" class="data row1 col8" >2.030000</td>
#       <td id="T_ce092_row1_col9" class="data row1 col9" >3.030000</td>
#       <td id="T_ce092_row1_col10" class="data row1 col10" >0.990000</td>
#       <td id="T_ce092_row1_col11" class="data row1 col11" >103</td>
#     </tr>
#     <tr>
#       <th id="T_ce092_level0_row2" class="row_heading level0 row2" >137</th>
#       <td id="T_ce092_row2_col0" class="data row2 col0" >100-105</td>
#       <td id="T_ce092_row2_col1" class="data row2 col1" >25-35°</td>
#       <td id="T_ce092_row2_col2" class="data row2 col2" >-9 to 9°</td>
#       <td id="T_ce092_row2_col3" class="data row2 col3" >0.130000</td>
#       <td id="T_ce092_row2_col4" class="data row2 col4" >0.030000</td>
#       <td id="T_ce092_row2_col5" class="data row2 col5" >0.060000</td>
#       <td id="T_ce092_row2_col6" class="data row2 col6" >-0.000000</td>
#       <td id="T_ce092_row2_col7" class="data row2 col7" >-0.220000</td>
#       <td id="T_ce092_row2_col8" class="data row2 col8" >1.220000</td>
#       <td id="T_ce092_row2_col9" class="data row2 col9" >2.000000</td>
#       <td id="T_ce092_row2_col10" class="data row2 col10" >0.740000</td>
#       <td id="T_ce092_row2_col11" class="data row2 col11" >131</td>
#     </tr>
#     <tr>
#       <th id="T_ce092_level0_row3" class="row_heading level0 row
# <style type="text/css">
# #T_48c03_row0_col3, #T_48c03_row1_col7, #T_48c03_row3_col7, #T_48c03_row7_col3, #T_48c03_row8_col6, #T_48c03_row9_col7 {
#   background-color: #f4f4ff;
#   color: #000000;
# }
# #T_48c03_row0_col4, #T_48c03_row1_col4 {
#   background-color: #ffeaea;
#   color: #000000;
# }
# #T_48c03_row0_col5 {
#   background-color: #ffd0d0;
#   color: #000000;
# }
# #T_48c03_row0_col6, #T_48c03_row9_col3 {
#   background-color: #fcfcff;
#   color: #000000;
# }
# #T_48c03_row0_col7 {
#   background-color: #ccccff;
#   color: #000000;
# }
# #T_48c03_row0_col8, #T_48c03_row1_col5 {
#   background-color: #eaeaff;
#   color: #000000;
# }
# #T_48c03_row0_col9 {
#   background-color: #ffd4d4;
#   color: #000000;
# }
# #T_48c03_row0_col10, #T_48c03_row7_col8 {
#   background-color: #ff9898;
#   color: #000000;
# }
# #T_48c03_row1_col3, #T_48c03_row2_col6, #T_48c03_row4_col3, #T_48c03_row5_col3, #T_48c03_row5_col6, #T_48c03_row6_col3, #T_48c03_row6_col6, #T_48c03_row7_col6, #T_48c03_row9_col6 {
#   background-color: #fffefe;
#   color: #000000;
# }
# #T_48c03_row1_col6, #T_48c03_row3_col10, #T_48c03_row5_col4, #T_48c03_row6_col4, #T_48c03_row7_col4 {
#   background-color: #fff4f4;
#   color: #000000;
# }
# #T_48c03_row1_col8 {
#   background-color: #3232ff;
#   color: #f1f1f1;
# }
# #T_48c03_row1_col9 {
#   background-color: #4646ff;
#   color: #f1f1f1;
# }
# #T_48c03_row1_col10 {
#   background-color: #ffe0e0;
#   color: #000000;
# }
# #T_48c03_row2_col3, #T_48c03_row3_col4, #T_48c03_row3_col5, #T_48c03_row4_col5 {
#   background-color: #fff0f0;
#   color: #000000;
# }
# #T_48c03_row2_col4 {
#   background-color: #ffeeee;
#   color: #000000;
# }
# #T_48c03_row2_col5, #T_48c03_row3_col6 {
#   background-color: #fafaff;
#   color: #000000;
# }
# #T_48c03_row2_col7 {
#   background-color: #e6e6ff;
#   color: #000000;
# }
# #T_48c03_row2_col8 {
#   background-color: #6464ff;
#   color: #f1f1f1;
# }
# #T_48c03_row2_col9, #T_48c03_row8_col9 {
#   background-color: #a0a0ff;
#   color: #f1f1f1;
# }
# #T_48c03_row2_col10 {
#   background-color: #ff9c9c;
#   color: #000000;
# }
# #T_48c03_row3_col3, #T_48c03_row8_col7 {
#   background-color: #f0f0ff;
#   color: #000000;
# }
# #T_48c03_row3_col8 {
#   background-color: #ceceff;
#   color: #000000;
# }
# #T_48c03_row3_col9 {
#   background-color: #dedeff;
#   color: #000000;
# }
# #T_48c03_row4_col4 {
#   background-color: #fff2f2;
#   color: #000000;
# }
# #T_48c03_row4_col6, #T_48c03_row5_col5, #T_48c03_row6_col7 {
#   background-color: #fffcfc;
#   color: #000000;
# }
# #T_48c03_row4_col7 {
#   background-color: #e2e2ff;
#   color: #000000;
# }
# #T_48c03_row4_col8, #T_48c03_row5_col8 {
#   background-color: #0e0eff;
#   color: #f1f1f1;
# }
# #T_48c03_row4_col9, #T_48c03_row6_col8 {
#   background-color: #3434ff;
#   color: #f1f1f1;
# }
# #T_48c03_row4_col10 {
#   background-color: #ffbcbc;
#   color: #000000;
# }
# #T_48c03_row5_col7, #T_48c03_row6_col5 {
#   background-color: #f2f2ff;
#   color: #000000;
# }
# #T_48c03_row5_col9 {
#   background-color: #2424ff;
#   color: #f1f1f1;
# }
# #T_48c03_row5_col10 {
#   background-color: #ffdcdc;
#   color: #000000;
# }
# #T_48c03_row6_col9 {
#   background-color: #3c3cff;
#   color: #f1f1f1;
# }
# #T_48c03_row6_col10 {
#   background-color: #fffafa;
#   color: #000000;
# }
# #T_48c03_row7_col5, #T_48c03_row8_col10 {
#   background-color: #ffdede;
#   color: #000000;
# }
# #T_48c03_row7_col7 {
#   background-color: #e0e0ff;
#   color: #000000;
# }
# #T_48c03_row7_col9 {
#   background-color: #ff7a7a;
#   color: #f1f1f1;
# }
# #T_48c03_row7_col10 {
#   background-color: #ffcece;
#   color: #000000;
# }
# #T_48c03_row8_col3 {
#   background-color: #f8f8ff;
#   color: #000000;
# }
# #T_48c03_row8_col4, #T_48c03_row9_col4, #T_48c03_row9_col5 {
#   background-color: #fff8f8;
#   color: #000000;
# }
# #T_48c03_row8_col5 {
#   background-color: #ffe8e8;
#   color: #000000;
# }
# #T_48c03_row8_col8 {
#   background-color: #8686ff;
#   color: #f1f1f1;
# }
# #T_48c03_row9_col8 {
#   background-color: #4040ff;
#   color: #f1f1f1;
# }
# #T_48c03_row9_col9 {
#   background-color: #5252ff;
#   color: #f1f1f1;
# }
# #T_48c03_row9_col10 {
#   background-color: #ffe2e2;
#   color: #000000;
# }
# </style>
# <table id="T_48c03">
#   <caption>Δ3B</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48c03_level0_col0" class="col_heading level0 col0" >EV</th>
#       <th id="T_48c03_level0_col1" class="col_heading level0 col1" >LA</th>
#       <th id="T_48c03_level0_col2" class="col_heading level0 col2" >SA</th>
#       <th id="T_48c03_level0_col3" class="col_heading level0 col3" >ΔHR</th>
#       <th id="T_48c03_level0_col4" class="col_heading level0 col4" >Δ3B</th>
#       <th id="T_48c03_level0_col5" class="col_heading level0 col5" >Δ2B</th>
#       <th id="T_48c03_level0_col6" class="col_heading level0 col6" >Δ1B</th>
#       <th id="T_48c03_level0_col7" class="col_heading level0 col7" >ΔOut</th>
#       <th id="T_48c03_level0_col8" class="col_heading level0 col8" >Bases_nCoors</th>
#       <th id="T_48c03_level0_col9" class="col_heading level0 col9" >Bases_Coors</th>
#       <th id="T_48c03_level0_col10" class="col_heading level0 col10" >ΔBases</th>
#       <th id="T_48c03_level0_col11" class="col_heading level0 col11" >n_Coors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48c03_level0_row0" class="row_heading level0 row0" >114</th>
#       <td id="T_48c03_row0_col0" class="data row0 col0" >95-100</td>
#       <td id="T_48c03_row0_col1" class="data row0 col1" >25-35°</td>
#       <td id="T_48c03_row0_col2" class="data row0 col2" >27 to 45°</td>
#       <td id="T_48c03_row0_col3" class="data row0 col3" >-0.040000</td>
#       <td id="T_48c03_row0_col4" class="data row0 col4" >0.080000</td>
#       <td id="T_48c03_row0_col5" class="data row0 col5" >0.180000</td>
#       <td id="T_48c03_row0_col6" class="data row0 col6" >-0.010000</td>
#       <td id="T_48c03_row0_col7" class="data row0 col7" >-0.200000</td>
#       <td id="T_48c03_row0_col8" class="data row0 col8" >1.840000</td>
#       <td id="T_48c03_row0_col9" class="data row0 col9" >2.330000</td>
#       <td id="T_48c03_row0_col10" class="data row0 col10" >0.400000</td>
#       <td id="T_48c03_row0_col11" class="data row0 col11" >102</td>
#     </tr>
#     <tr>
#       <th id="T_48c03_level0_row1" class="row_heading level0 row1" >34</th>
#       <td id="T_48c03_row1_col0" class="data row1 col0" >80-85</td>
#       <td id="T_48c03_row1_col1" class="data row1 col1" >10-25°</td>
#       <td id="T_48c03_row1_col2" class="data row1 col2" >27 to 45°</td>
#       <td id="T_48c03_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_48c03_row1_col4" class="data row1 col4" >0.080000</td>
#       <td id="T_48c03_row1_col5" class="data row1 col5" >-0.080000</td>
#       <td id="T_48c03_row1_col6" class="data row1 col6" >0.040000</td>
#       <td id="T_48c03_row1_col7" class="data row1 col7" >-0.040000</td>
#       <td id="T_48c03_row1_col8" class="data row1 col8" >0.400000</td>
#       <td id="T_48c03_row1_col9" class="data row1 col9" >0.560000</td>
#       <td id="T_48c03_row1_col10" class="data row1 col10" >0.120000</td>
#       <td id="T_48c03_row1_col11" class="data row1 col11" >82</td>
#     </tr>
#     <tr>
#       <th id="T_48c03_level0_row2" class="row_heading level0 row2" >119</th>
#       <td id="T_48c03_row2_col0" class="data row2 col0" >95-100</td>
#       <td id="T_48c03_row2_col1" class="data row2 col1" >35-50°</td>
#       <td id="T_48c03_row2_col2" class="data row2 col2" >27 to 45°</td>
#       <td id="T_48c03_row2_col3" class="data row2 col3" >0.060000</td>
#       <td id="T_48c03_row2_col4" class="data row2 col4" >0.070000</td>
#       <td id="T_48c03_row2_col5" class="data row2 col5" >-0.020000</td>
#       <td id="T_48c03_row2_col6" class="data row2 col6" >-0.000000</td>
#       <td id="T_48c03_row2_col7" class="data row2 col7" >-0.100000</td>
#       <td id="T_48c03_row2_col8" class="data row2 col8" >0.790000</td>
#       <td id="T_48c03_row2_col9" class="data row2 col9" >1.250000</td>
#       <td id="T_48c03_row2_col10" class="data row2 col10" >0.390000</td>
#       <td id="T_48c03_row2_col11" class="data row2 col11" >61</td>
#     </tr>
#     <tr>
#       <th id="T_48c03_level0_row3" class="row_heading level0 row3" >156</th>
#       <td id="T_48c03_row3_col0" class="data row3 col0" >105-110</td>
#       <td id="T_48c03_row
# <style type="text/css">
# #T_bb3c0_row0_col3, #T_bb3c0_row9_col5 {
#   background-color: #fff0f0;
#   color: #000000;
# }
# #T_bb3c0_row0_col4, #T_bb3c0_row2_col4, #T_bb3c0_row5_col4, #T_bb3c0_row7_col4 {
#   background-color: #fff8f8;
#   color: #000000;
# }
# #T_bb3c0_row0_col5, #T_bb3c0_row4_col10 {
#   background-color: #ffc6c6;
#   color: #000000;
# }
# #T_bb3c0_row0_col6, #T_bb3c0_row1_col6, #T_bb3c0_row4_col3 {
#   background-color: #fcfcff;
#   color: #000000;
# }
# #T_bb3c0_row0_col7 {
#   background-color: #b0b0ff;
#   color: #000000;
# }
# #T_bb3c0_row0_col8 {
#   background-color: #6262ff;
#   color: #f1f1f1;
# }
# #T_bb3c0_row0_col9 {
#   background-color: #cacaff;
#   color: #000000;
# }
# #T_bb3c0_row0_col10 {
#   background-color: #ff3a3a;
#   color: #f1f1f1;
# }
# #T_bb3c0_row1_col3, #T_bb3c0_row3_col3, #T_bb3c0_row5_col6, #T_bb3c0_row7_col7 {
#   background-color: #f4f4ff;
#   color: #000000;
# }
# #T_bb3c0_row1_col4, #T_bb3c0_row7_col5, #T_bb3c0_row7_col10, #T_bb3c0_row9_col10 {
#   background-color: #ffeaea;
#   color: #000000;
# }
# #T_bb3c0_row1_col5 {
#   background-color: #ffd0d0;
#   color: #000000;
# }
# #T_bb3c0_row1_col7 {
#   background-color: #ccccff;
#   color: #000000;
# }
# #T_bb3c0_row1_col8, #T_bb3c0_row6_col6 {
#   background-color: #eaeaff;
#   color: #000000;
# }
# #T_bb3c0_row1_col9 {
#   background-color: #ffd4d4;
#   color: #000000;
# }
# #T_bb3c0_row1_col10, #T_bb3c0_row3_col8 {
#   background-color: #ff9898;
#   color: #000000;
# }
# #T_bb3c0_row2_col3, #T_bb3c0_row8_col7, #T_bb3c0_row9_col7 {
#   background-color: #fafaff;
#   color: #000000;
# }
# #T_bb3c0_row2_col5 {
#   background-color: #ffdcdc;
#   color: #000000;
# }
# #T_bb3c0_row2_col6, #T_bb3c0_row4_col6 {
#   background-color: #fffcfc;
#   color: #000000;
# }
# #T_bb3c0_row2_col7 {
#   background-color: #d6d6ff;
#   color: #000000;
# }
# #T_bb3c0_row2_col8 {
#   background-color: #4646ff;
#   color: #f1f1f1;
# }
# #T_bb3c0_row2_col9 {
#   background-color: #6e6eff;
#   color: #f1f1f1;
# }
# #T_bb3c0_row2_col10 {
#   background-color: #ffb4b4;
#   color: #000000;
# }
# #T_bb3c0_row3_col4, #T_bb3c0_row6_col10 {
#   background-color: #fff4f4;
#   color: #000000;
# }
# #T_bb3c0_row3_col5, #T_bb3c0_row5_col10 {
#   background-color: #ffdede;
#   color: #000000;
# }
# #T_bb3c0_row3_col6, #T_bb3c0_row6_col7, #T_bb3c0_row8_col3, #T_bb3c0_row8_col4, #T_bb3c0_row9_col3, #T_bb3c0_row9_col4 {
#   background-color: #fffefe;
#   color: #000000;
# }
# #T_bb3c0_row3_col7, #T_bb3c0_row4_col7 {
#   background-color: #e0e0ff;
#   color: #000000;
# }
# #T_bb3c0_row3_col9 {
#   background-color: #ff7a7a;
#   color: #f1f1f1;
# }
# #T_bb3c0_row3_col10 {
#   background-color: #ffcece;
#   color: #000000;
# }
# #T_bb3c0_row4_col4, #T_bb3c0_row6_col4 {
#   background-color: #fffafa;
#   color: #000000;
# }
# #T_bb3c0_row4_col5 {
#   background-color: #ffe6e6;
#   color: #000000;
# }
# #T_bb3c0_row4_col8 {
#   background-color: #7c7cff;
#   color: #f1f1f1;
# }
# #T_bb3c0_row4_col9 {
#   background-color: #9898ff;
#   color: #f1f1f1;
# }
# #T_bb3c0_row5_col3, #T_bb3c0_row6_col3, #T_bb3c0_row7_col3, #T_bb3c0_row7_col6, #T_bb3c0_row9_col6 {
#   background-color: #f8f8ff;
#   color: #000000;
# }
# #T_bb3c0_row5_col5, #T_bb3c0_row6_col5, #T_bb3c0_row8_col10 {
#   background-color: #ffe8e8;
#   color: #000000;
# }
# #T_bb3c0_row5_col7 {
#   background-color: #f0f0ff;
#   color: #000000;
# }
# #T_bb3c0_row5_col8 {
#   background-color: #8686ff;
#   color: #f1f1f1;
# }
# #T_bb3c0_row5_col9 {
#   background-color: #a0a0ff;
#   color: #f1f1f1;
# }
# #T_bb3c0_row6_col8 {
#   background-color: #bcbcff;
#   color: #000000;
# }
# #T_bb3c0_row6_col9 {
#   background-color: #ceceff;
#   color: #000000;
# }
# #T_bb3c0_row7_col8 {
#   background-color: #8080ff;
#   color: #f1f1f1;
# }
# #T_bb3c0_row7_col9 {
#   background-color: #9090ff;
#   color: #f1f1f1;
# }
# #T_bb3c0_row8_col5 {
#   background-color: #ffeeee;
#   color: #000000;
# }
# #T_bb3c0_row8_col6 {
#   background-color: #f2f2ff;
#   color: #000000;
# }
# #T_bb3c0_row8_col8 {
#   background-color: #3c3cff;
#   color: #f1f1f1;
# }
# #T_bb3c0_row8_col9 {
#   background-color: #4e4eff;
#   color: #f1f1f1;
# }
# #T_bb3c0_row9_col8 {
#   background-color: #2222ff;
#   color: #f1f1f1;
# }
# #T_bb3c0_row9_col9 {
#   background-color: #3030ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bb3c0">
#   <caption>Δ2B</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb3c0_level0_col0" class="col_heading level0 col0" >EV</th>
#       <th id="T_bb3c0_level0_col1" class="col_heading level0 col1" >LA</th>
#       <th id="T_bb3c0_level0_col2" class="col_heading level0 col2" >SA</th>
#       <th id="T_bb3c0_level0_col3" class="col_heading level0 col3" >ΔHR</th>
#       <th id="T_bb3c0_level0_col4" class="col_heading level0 col4" >Δ3B</th>
#       <th id="T_bb3c0_level0_col5" class="col_heading level0 col5" >Δ2B</th>
#       <th id="T_bb3c0_level0_col6" class="col_heading level0 col6" >Δ1B</th>
#       <th id="T_bb3c0_level0_col7" class="col_heading level0 col7" >ΔOut</th>
#       <th id="T_bb3c0_level0_col8" class="col_heading level0 col8" >Bases_nCoors</th>
#       <th id="T_bb3c0_level0_col9" class="col_heading level0 col9" >Bases_Coors</th>
#       <th id="T_bb3c0_level0_col10" class="col_heading level0 col10" >ΔBases</th>
#       <th id="T_bb3c0_level0_col11" class="col_heading level0 col11" >n_Coors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb3c0_level0_row0" class="row_heading level0 row0" >113</th>
#       <td id="T_bb3c0_row0_col0" class="data row0 col0" >95-100</td>
#       <td id="T_bb3c0_row0_col1" class="data row0 col1" >25-35°</td>
#       <td id="T_bb3c0_row0_col2" class="data row0 col2" >9 to 27°</td>
#       <td id="T_bb3c0_row0_col3" class="data row0 col3" >0.060000</td>
#       <td id="T_bb3c0_row0_col4" class="data row0 col4" >0.030000</td>
#       <td id="T_bb3c0_row0_col5" class="data row0 col5" >0.220000</td>
#       <td id="T_bb3c0_row0_col6" class="data row0 col6" >-0.010000</td>
#       <td id="T_bb3c0_row0_col7" class="data row0 col7" >-0.310000</td>
#       <td id="T_bb3c0_row0_col8" class="data row0 col8" >0.770000</td>
#       <td id="T_bb3c0_row0_col9" class="data row0 col9" >1.580000</td>
#       <td id="T_bb3c0_row0_col10" class="data row0 col10" >0.770000</td>
#       <td id="T_bb3c0_row0_col11" class="data row0 col11" >156</td>
#     </tr>
#     <tr>
#       <th id="T_bb3c0_level0_row1" class="row_heading level0 row1" >114</th>
#       <td id="T_bb3c0_row1_col0" class="data row1 col0" >95-100</td>
#       <td id="T_bb3c0_row1_col1" class="data row1 col1" >25-35°</td>
#       <td id="T_bb3c0_row1_col2" class="data row1 col2" >27 to 45°</td>
#       <td id="T_bb3c0_row1_col3" class="data row1 col3" >-0.040000</td>
#       <td id="T_bb3c0_row1_col4" class="data row1 col4" >0.080000</td>
#       <td id="T_bb3c0_row1_col5" class="data row1 col5" >0.180000</td>
#       <td id="T_bb3c0_row1_col6" class="data row1 col6" >-0.010000</td>
#       <td id="T_bb3c0_row1_col7" class="data row1 col7" >-0.200000</td>
#       <td id="T_bb3c0_row1_col8" class="data row1 col8" >1.840000</td>
#       <td id="T_bb3c0_row1_col9" class="data row1 col9" >2.330000</td>
#       <td id="T_bb3c0_row1_col10" class="data row1 col10" >0.400000</td>
#       <td id="T_bb3c0_row1_col11" class="data row1 col11" >102</td>
#     </tr>
#     <tr>
#       <th id="T_bb3c0_level0_row2" class="row_heading level0 row2" >89</th>
#       <td id="T_bb3c0_row2_col0" class="data row2 col0" >90-95</td>
#       <td id="T_bb3c0_row2_col1" class="data row2 col1" >25-35°</td>
#       <td id="T_bb3c0_row2_col2" class="data row2 col2" >27 to 45°</td>
#       <td id="T_bb3c0_row2_col3" class="data row2 col3" >-0.020000</td>
#       <td id="T_bb3c0_row2_col4" class="data row2 col4" >0.030000</td>
#       <td id="T_bb3c0_row2_col5" class="data row2 col5" >0.140000</td>
#       <td id="T_bb3c0_row2_col6" class="data row2 col6" >0.010000</td>
#       <td id="T_bb3c0_row2_col7" class="data row2 col7" >-0.160000</td>
#       <td id="T_bb3c0_row2_col8" class="data row2 col8" >0.560000</td>
#       <td id="T_bb3c0_row2_col9" class="data row2 col9" >0.860000</td>
#       <td id="T_bb3c0_row2_col10" class="data row2 col10" >0.290000</td>
#       <td id="T_bb3c0_row2_col11" class="data row2 col11" >109</td>
#     </tr>
#     <tr>
# ...
# #T_6912b_row0_col3, #T_6912b_row1_col3, #T_6912b_row1_col4, #T_6912b_row2_col3, #T_6912b_row2_col4, #T_6912b_row3_col3, #T_6912b_row3_col4, #T_6912b_row3_col5, #T_6912b_row4_col3, #T_6912b_row4_col4, #T_6912b_row5_col3, #T_6912b_row5_col4, #T_6912b_row5_col5, #T_6912b_row6_col3, #T_6912b_row7_col3, #T_6912b_row7_col4, #T_6912b_row7_col5, #T_6912b_row8_col3, #T_6912b_row8_col4, #T_6912b_row9_col3, #T_6912b_row9_col4 {
#   background-color: #fffefe;
#   color: #000000;
# }
# #T_6912b_row0_col4, #T_6912b_row1_col5, #T_6912b_row2_col5 {
#   background-color: #fcfcff;
#   color: #000000;
# }
# #T_6912b_row0_col5, #T_6912b_row2_col10 {
#   background-color: #eeeeff;
#   color: #000000;
# }
# #T_6912b_row0_col6, #T_6912b_row6_col5, #T_6912b_row8_col10, #T_6912b_row9_col5 {
#   background-color: #fffcfc;
#   color: #000000;
# }
# #T_6912b_row0_col7 {
#   background-color: #ffeeee;
#   color: #000000;
# }
# #T_6912b_row0_col8, #T_6912b_row4_col8, #T_6912b_row8_col9 {
#   background-color: #2222ff;
#   color: #f1f1f1;
# }
# #T_6912b_row0_col9, #T_6912b_row9_col8, #T_6912b_row9_col9 {
#   background-color: #0c0cff;
#   color: #f1f1f1;
# }
# #T_6912b_row0_col10 {
#   background-color: #d6d6ff;
#   color: #000000;
# }
# #T_6912b_row1_col6, #T_6912b_row3_col10, #T_6912b_row4_col10 {
#   background-color: #f2f2ff;
#   color: #000000;
# }
# #T_6912b_row1_col7 {
#   background-color: #fff0f0;
#   color: #000000;
# }
# #T_6912b_row1_col8 {
#   background-color: #0202ff;
#   color: #f1f1f1;
# }
# #T_6912b_row1_col9, #T_6912b_row3_col8, #T_6912b_row3_col9, #T_6912b_row5_col8, #T_6912b_row5_col9 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_6912b_row1_col10 {
#   background-color: #eaeaff;
#   color: #000000;
# }
# #T_6912b_row2_col6, #T_6912b_row3_col6, #T_6912b_row5_col10 {
#   background-color: #f4f4ff;
#   color: #000000;
# }
# #T_6912b_row2_col7 {
#   background-color: #fff2f2;
#   color: #000000;
# }
# #T_6912b_row2_col8 {
#   background-color: #0a0aff;
#   color: #f1f1f1;
# }
# #T_6912b_row2_col9 {
#   background-color: #0606ff;
#   color: #f1f1f1;
# }
# #T_6912b_row3_col7, #T_6912b_row4_col7 {
#   background-color: #fff4f4;
#   color: #000000;
# }
# #T_6912b_row4_col5, #T_6912b_row4_col6, #T_6912b_row6_col4, #T_6912b_row7_col10 {
#   background-color: #fafaff;
#   color: #000000;
# }
# #T_6912b_row4_col9 {
#   background-color: #1e1eff;
#   color: #f1f1f1;
# }
# #T_6912b_row5_col6, #T_6912b_row6_col6, #T_6912b_row7_col6, #T_6912b_row9_col6, #T_6912b_row9_col10 {
#   background-color: #f8f8ff;
#   color: #000000;
# }
# #T_6912b_row5_col7, #T_6912b_row6_col7, #T_6912b_row7_col7, #T_6912b_row8_col5, #T_6912b_row8_col7, #T_6912b_row9_col7 {
#   background-color: #fff8f8;
#   color: #000000;
# }
# #T_6912b_row6_col8 {
#   background-color: #1a1aff;
#   color: #f1f1f1;
# }
# #T_6912b_row6_col9 {
#   background-color: #1414ff;
#   color: #f1f1f1;
# }
# #T_6912b_row6_col10, #T_6912b_row8_col6 {
#   background-color: #f0f0ff;
#   color: #000000;
# }
# #T_6912b_row7_col8 {
#   background-color: #0e0eff;
#   color: #f1f1f1;
# }
# #T_6912b_row7_col9 {
#   background-color: #1010ff;
#   color: #f1f1f1;
# }
# #T_6912b_row8_col8 {
#   background-color: #1818ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6912b">
#   <caption>ΔOut</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6912b_level0_col0" class="col_heading level0 col0" >EV</th>
#       <th id="T_6912b_level0_col1" class="col_heading level0 col1" >LA</th>
#       <th id="T_6912b_level0_col2" class="col_heading level0 col2" >SA</th>
#       <th id="T_6912b_level0_col3" class="col_heading level0 col3" >ΔHR</th>
#       <th id="T_6912b_level0_col4" class="col_heading level0 col4" >Δ3B</th>
#       <th id="T_6912b_level0_col5" class="col_heading level0 col5" >Δ2B</th>
#       <th id="T_6912b_level0_col6" class="col_heading level0 col6" >Δ1B</th>
#       <th id="T_6912b_level0_col7" class="col_heading level0 col7" >ΔOut</th>
#       <th id="T_6912b_level0_col8" class="col_heading level0 col8" >Bases_nCoors</th>
#       <th id="T_6912b_level0_col9" class="col_heading level0 col9" >Bases_Coors</th>
#       <th id="T_6912b_level0_col10" class="col_heading level0 col10" >ΔBases</th>
#       <th id="T_6912b_level0_col11" class="col_heading level0 col11" >n_Coors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6912b_level0_row0" class="row_heading level0 row0" >60</th>
#       <td id="T_6912b_row0_col0" class="data row0 col0" >85-90</td>
#       <td id="T_6912b_row0_col1" class="data row0 col1" >25-35°</td>
#       <td id="T_6912b_row0_col2" class="data row0 col2" >-45 to -27°</td>
#       <td id="T_6912b_row0_col3" class="data row0 col3" >-0.000000</td>
#       <td id="T_6912b_row0_col4" class="data row0 col4" >-0.010000</td>
#       <td id="T_6912b_row0_col5" class="data row0 col5" >-0.070000</td>
#       <td id="T_6912b_row0_col6" class="data row0 col6" >0.010000</td>
#       <td id="T_6912b_row0_col7" class="data row0 col7" >0.070000</td>
#       <td id="T_6912b_row0_col8" class="data row0 col8" >0.270000</td>
#       <td id="T_6912b_row0_col9" class="data row0 col9" >0.100000</td>
#       <td id="T_6912b_row0_col10" class="data row0 col10" >-0.160000</td>
#       <td id="T_6912b_row0_col11" class="data row0 col11" >61</td>
#     </tr>
#     <tr>
#       <th id="T_6912b_level0_row1" class="row_heading level0 row1" >57</th>
#       <td id="T_6912b_row1_col0" class="data row1 col0" >85-90</td>
#       <td id="T_6912b_row1_col1" class="data row1 col1" >10-25°</td>
#       <td id="T_6912b_row1_col2" class="data row1 col2" >-9 to 9°</td>
#       <td id="T_6912b_row1_col3" class="data row1 col3" >-0.000000</td>
#       <td id="T_6912b_row1_col4" class="data row1 col4" >-0.000000</td>
#       <td id="T_6912b_row1_col5" class="data row1 col5" >-0.010000</td>
#       <td id="T_6912b_row1_col6" class="data row1 col6" >-0.050000</td>
#       <td id="T_6912b_row1_col7" class="data row1 col7" >0.060000</td>
#       <td id="T_6912b_row1_col8" class="data row1 col8" >0.030000</td>
#       <td id="T_6912b_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_6912b_row1_col10" class="data row1 col10" >-0.080000</td>
#       <td id="T_6912b_row1_col11" class="data row1 col11" >119</td>
#     </tr>
#     <tr>
#       <th id="T_6912b_level0_row2" class="row_heading level0 row2" >25</th>
#       <td id="T_6912b_row2_col0" class="data row2 col0" >80-85</td>
#       <td id="T_6912b_row2_col1" class="data row2 col1" ><10°</td>
#       <td id="T_6912b_row2_col2" class="data row2 col2" >-45 to -27°</td>
#       <td id="T_6912b_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_6912b_row2_col4" class="data row2 col4" >-0.000000</td>
#       <td id="T_6912b_row2_col5" class="data row2 col5" >-0.010000</td>
#       <td id="T_6912b_row2_col6" class="data row2 col6" >-0.040000</td>
#       <td id="T_6912b_row2_col7" class="data row2 col7" >0.050000</td>
#       <td id="T_6912b_row2_col8" class="data row2 col8" >0.090000</td>
#       <td id="T_6912b_row2_col9" class="data row2 col9" >0.060000</td>
#       <td id="T_6912b_row2_col10" class="data row2 col10" >-0.070000</td>
#       <td id="T_6912b_row2_col11" class="data row2 col11" >226</td>
#     </tr>
#     <tr>
#       <th id="T_6912b_level0_row3" class="row_heading level0 row3" >27</th>
#       <td id="T_6912b_row3_col0" class="data row3 col0" >80-85</td>
#       <td id="T_6912b_row3_col1" class="data row3 col1" ><10°</td>
#       <td id="T_6912b_row3_col2" class="data row3 col2" >-9 to 9°</td>
#       <td id="T_6912b_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_6912b_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_6912b_row3_col5" class="data row3 col5" >-0.000000</td>
#       <td id="T_6912b_row3_col6" class="data row3 col6" >-0.040000</td>
#       <td id="T_6912b_row3_col7" class="data row3 col7" >0.040000</td>
#       <td id="T_6912b_row3_col8" class="data row3 col8" >0.000000</td>
#       <td id="T_6912b_row3_col9" class="data row3 col9" >0.000000</td>
#       <td id="T_6912b_row3_col10" class="data row3 col10" >-0.050000</td>
#       <td id="T_6912b_row3_col11" class="data row3 col11" >95</td>
#     </tr>
#     <tr>
#       <th id="T_6912b_level0_row4" class="row_heading level0 row4" >125</th>
# <style type="text/css">
# #T_58216_row0_col3, #T_58216_row3_col5, #T_58216_row4_col5 {
#   background-color: #fff0f0;
#   color: #000000;
# }
# #T_58216_row0_col4, #T_58216_row3_col4, #T_58216_row4_col4, #T_58216_row6_col4 {
#   background-color: #fff8f8;
#   color: #000000;
# }
# #T_58216_row0_col5 {
#   background-color: #ffc6c6;
#   color: #000000;
# }
# #T_58216_row0_col6, #T_58216_row2_col6, #T_58216_row5_col6, #T_58216_row7_col5 {
#   background-color: #fcfcff;
#   color: #000000;
# }
# #T_58216_row0_col7 {
#   background-color: #b0b0ff;
#   color: #000000;
# }
# #T_58216_row0_col8 {
#   background-color: #6262ff;
#   color: #f1f1f1;
# }
# #T_58216_row0_col9, #T_58216_row4_col7 {
#   background-color: #cacaff;
#   color: #000000;
# }
# #T_58216_row0_col10 {
#   background-color: #ff3a3a;
#   color: #f1f1f1;
# }
# #T_58216_row1_col3, #T_58216_row6_col10 {
#   background-color: #ffb4b4;
#   color: #000000;
# }
# #T_58216_row1_col4, #T_58216_row1_col6, #T_58216_row2_col4, #T_58216_row3_col6, #T_58216_row3_col9, #T_58216_row4_col6, #T_58216_row7_col3, #T_58216_row7_col4, #T_58216_row8_col3, #T_58216_row8_col5, #T_58216_row9_col4, #T_58216_row9_col6 {
#   background-color: #fffefe;
#   color: #000000;
# }
# #T_58216_row1_col5 {
#   background-color: #f8f8ff;
#   color: #000000;
# }
# #T_58216_row1_col7 {
#   background-color: #c0c0ff;
#   color: #000000;
# }
# #T_58216_row1_col8 {
#   background-color: #7070ff;
#   color: #f1f1f1;
# }
# #T_58216_row1_col9, #T_58216_row2_col5, #T_58216_row6_col3 {
#   background-color: #fafaff;
#   color: #000000;
# }
# #T_58216_row1_col10 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_58216_row2_col3, #T_58216_row4_col8 {
#   background-color: #ffbcbc;
#   color: #000000;
# }
# #T_58216_row2_col7 {
#   background-color: #c4c4ff;
#   color: #000000;
# }
# #T_58216_row2_col8, #T_58216_row6_col6, #T_58216_row8_col4 {
#   background-color: #fffcfc;
#   color: #000000;
# }
# #T_58216_row2_col9, #T_58216_row9_col10 {
#   background-color: #ff7c7c;
#   color: #f1f1f1;
# }
# #T_58216_row2_col10 {
#   background-color: #ff0202;
#   color: #f1f1f1;
# }
# #T_58216_row3_col3 {
#   background-color: #ffdede;
#   color: #000000;
# }
# #T_58216_row3_col7 {
#   background-color: #c6c6ff;
#   color: #000000;
# }
# #T_58216_row3_col8 {
#   background-color: #9c9cff;
#   color: #f1f1f1;
# }
# #T_58216_row3_col10 {
#   background-color: #ff4242;
#   color: #f1f1f1;
# }
# #T_58216_row4_col3, #T_58216_row8_col6, #T_58216_row9_col3 {
#   background-color: #ffe0e0;
#   color: #000000;
# }
# #T_58216_row4_col9 {
#   background-color: #ff6262;
#   color: #f1f1f1;
# }
# #T_58216_row4_col10 {
#   background-color: #ff5454;
#   color: #f1f1f1;
# }
# #T_58216_row5_col3 {
#   background-color: #f4f4ff;
#   color: #000000;
# }
# #T_58216_row5_col4 {
#   background-color: #ffeaea;
#   color: #000000;
# }
# #T_58216_row5_col5 {
#   background-color: #ffd0d0;
#   color: #000000;
# }
# #T_58216_row5_col7 {
#   background-color: #ccccff;
#   color: #000000;
# }
# #T_58216_row5_col8 {
#   background-color: #eaeaff;
#   color: #000000;
# }
# #T_58216_row5_col9 {
#   background-color: #ffd4d4;
#   color: #000000;
# }
# #T_58216_row5_col10 {
#   background-color: #ff9898;
#   color: #000000;
# }
# #T_58216_row6_col5, #T_58216_row7_col6 {
#   background-color: #ffdcdc;
#   color: #000000;
# }
# #T_58216_row6_col7 {
#   background-color: #d6d6ff;
#   color: #000000;
# }
# #T_58216_row6_col8 {
#   background-color: #4646ff;
#   color: #f1f1f1;
# }
# #T_58216_row6_col9 {
#   background-color: #6e6eff;
#   color: #f1f1f1;
# }
# #T_58216_row7_col7, #T_58216_row8_col7, #T_58216_row9_col7 {
#   background-color: #dedeff;
#   color: #000000;
# }
# #T_58216_row7_col8, #T_58216_row8_col8 {
#   background-color: #0202ff;
#   color: #f1f1f1;
# }
# #T_58216_row7_col9 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_58216_row7_col10 {
#   background-color: #ffe2e2;
#   color: #000000;
# }
# #T_58216_row8_col9 {
#   background-color: #0808ff;
#   color: #f1f1f1;
# }
# #T_58216_row8_col10 {
#   background-color: #ffd8d8;
#   color: #000000;
# }
# #T_58216_row9_col5 {
#   background-color: #fffafa;
#   color: #000000;
# }
# #T_58216_row9_col8 {
#   background-color: #ff6c6c;
#   color: #f1f1f1;
# }
# #T_58216_row9_col9 {
#   background-color: #ff2a2a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_58216">
#   <caption>ΔOut</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58216_level0_col0" class="col_heading level0 col0" >EV</th>
#       <th id="T_58216_level0_col1" class="col_heading level0 col1" >LA</th>
#       <th id="T_58216_level0_col2" class="col_heading level0 col2" >SA</th>
#       <th id="T_58216_level0_col3" class="col_heading level0 col3" >ΔHR</th>
#       <th id="T_58216_level0_col4" class="col_heading level0 col4" >Δ3B</th>
#       <th id="T_58216_level0_col5" class="col_heading level0 col5" >Δ2B</th>
#       <th id="T_58216_level0_col6" class="col_heading level0 col6" >Δ1B</th>
#       <th id="T_58216_level0_col7" class="col_heading level0 col7" >ΔOut</th>
#       <th id="T_58216_level0_col8" class="col_heading level0 col8" >Bases_nCoors</th>
#       <th id="T_58216_level0_col9" class="col_heading level0 col9" >Bases_Coors</th>
#       <th id="T_58216_level0_col10" class="col_heading level0 col10" >ΔBases</th>
#       <th id="T_58216_level0_col11" class="col_heading level0 col11" >n_Coors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58216_level0_row0" class="row_heading level0 row0" >113</th>
#       <td id="T_58216_row0_col0" class="data row0 col0" >95-100</td>
#       <td id="T_58216_row0_col1" class="data row0 col1" >25-35°</td>
#       <td id="T_58216_row0_col2" class="data row0 col2" >9 to 27°</td>
#       <td id="T_58216_row0_col3" class="data row0 col3" >0.060000</td>
#       <td id="T_58216_row0_col4" class="data row0 col4" >0.030000</td>
#       <td id="T_58216_row0_col5" class="data row0 col5" >0.220000</td>
#       <td id="T_58216_row0_col6" class="data row0 col6" >-0.010000</td>
#       <td id="T_58216_row0_col7" class="data row0 col7" >-0.310000</td>
#       <td id="T_58216_row0_col8" class="data row0 col8" >0.770000</td>
#       <td id="T_58216_row0_col9" class="data row0 col9" >1.580000</td>
#       <td id="T_58216_row0_col10" class="data row0 col10" >0.770000</td>
#       <td id="T_58216_row0_col11" class="data row0 col11" >156</td>
#     </tr>
#     <tr>
#       <th id="T_58216_level0_row1" class="row_heading level0 row1" >115</th>
#       <td id="T_58216_row1_col0" class="data row1 col0" >95-100</td>
#       <td id="T_58216_row1_col1" class="data row1 col1" >35-50°</td>
#       <td id="T_58216_row1_col2" class="data row1 col2" >-45 to -27°</td>
#       <td id="T_58216_row1_col3" class="data row1 col3" >0.290000</td>
#       <td id="T_58216_row1_col4" class="data row1 col4" >-0.000000</td>
#       <td id="T_58216_row1_col5" class="data row1 col5" >-0.030000</td>
#       <td id="T_58216_row1_col6" class="data row1 col6" >-0.000000</td>
#       <td id="T_58216_row1_col7" class="data row1 col7" >-0.250000</td>
#       <td id="T_58216_row1_col8" class="data row1 col8" >0.890000</td>
#       <td id="T_58216_row1_col9" class="data row1 col9" >1.960000</td>
#       <td id="T_58216_row1_col10" class="data row1 col10" >1.070000</td>
#       <td id="T_58216_row1_col11" class="data row1 col11" >57</td>
#     </tr>
#     <tr>
#       <th id="T_58216_level0_row2" class="row_heading level0 row2" >110</th>
#       <td id="T_58216_row2_col0" class="data row2 col0" >95-100</td>
#       <td id="T_58216_row2_col1" class="data row2 col1" >25-35°</td>
#       <td id="T_58216_row2_col2" class="data row2 col2" >-45 to -27°</td>
#       <td id="T_58216_row2_col3" class="data row2 col3" >0.260000</td>
#       <td id="T_58216_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_58216_row2_col5" class="data row2 col5" >-0.020000</td>
#       <td id="T_58216_row2_col6" class="data row2 col6" >-0.010000</td>
#       <td id="T_58216_row2_col7" class="data row2 col7" >-0.230000</td>
#       <td id="T_58216_row2_col8" class="data row2 col8" >2.030000</td>
#       <td id="T_58216_row2_col9" class="data row2 col9" >3.030000</td>
#       <td id="T_58216_row2_col10" class="data row2 col10" >0.990000</td>
#       <td id="T_58216_row2_col11" class="data row2 col11" >103</td>
#     </tr>
#     <tr>
#       <th id="T_58216_level0_row3" class="row_heading level0 row

# %% [markdown]
# ## Plot spray charts

# %%
# Methods to plot spray chart
def draw_field(ax, r=415):
    theta = np.linspace(-np.pi/4, np.pi/4, 200)
    ax.plot(r*np.sin(theta), r*np.cos(theta), color='black', lw=1)
    ax.plot(154*np.sin(theta), 154*np.cos(theta), color='black', lw=1)
    ax.plot([0, -r/np.sqrt(2)], [0, r/np.sqrt(2)], color='black', lw=1)
    ax.plot([0, r/np.sqrt(2)], [0, r/np.sqrt(2)], color='black', lw=1)
    ax.scatter(0, 0, color='black', s=20)  # home plate

    return ax

def draw_wedge(ax, range: tuple=(-45,45), val=1, norm_factor=1, r=415):
    from matplotlib.patches import Wedge

    theta1 = 90 - range[0] 
    theta2 = 90 - range[1]
    alpha = np.abs(val) / norm_factor
    if val > 0:
        color = 'red'
    else:
        color = 'blue'
    
    wedge = Wedge(
        center=(0,0),
        r=r,
        theta1=theta2,
        theta2=theta1,
        facecolor=color,
        alpha=alpha
    )
    ax.add_patch(wedge)
    return ax

# %%
fig, axs = plt.subplots(5, 8, figsize=(18,8))

for i, ev_label in enumerate(ev_labels):
    for j, la_label in enumerate(la_labels):

        # General Plot
        ax = axs[j,i]
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_ylabel(f'LA: {la_label}')
        ax.set_xlabel(f'EV: {ev_label} mph')

        # Get subset
        sub_df = exp_outcomes.loc[exp_outcomes['EV'] == ev_label].loc[exp_outcomes['LA'] == la_label]
        if sub_df.shape[0] == 0:
            ax.axis('off')
            continue
        else:
            draw_field(ax)

        # Add wedges
        for k, r in sub_df.iterrows():
            range = (int(r['SA'].split()[0]), int(r['SA'].split()[-1][:-1]))
            ax = draw_wedge(ax, range, val=r['ΔBases'], norm_factor=max(np.abs(exp_outcomes['ΔBases']).max(), 1))

fig.suptitle('ΔBases at Coors Field')
fig.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(5, 8, figsize=(18,8))

for i, ev_label in enumerate(ev_labels):
    for j, la_label in enumerate(la_labels):

        # General Plot
        ax = axs[j,i]
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_ylabel(f'LA: {la_label}')
        ax.set_xlabel(f'EV: {ev_label} mph')

        # Get subset
        sub_df = exp_outcomes.loc[exp_outcomes['EV'] == ev_label].loc[exp_outcomes['LA'] == la_label]
        if sub_df.shape[0] == 0:
            ax.axis('off')
            continue
        else:
            draw_field(ax)

        # Add wedges
        for k, r in sub_df.iterrows():
            range = (int(r['SA'].split()[0]), int(r['SA'].split()[-1][:-1]))
            ax = draw_wedge(ax, range, val=r['ΔOut'], norm_factor=1)
            
fig.suptitle('ΔOut at Coors Field')
fig.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(5, 8, figsize=(18,8))

for i, ev_label in enumerate(ev_labels):
    for j, la_label in enumerate(la_labels):

        # General Plot
        ax = axs[j,i]
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_ylabel(f'LA: {la_label}')
        ax.set_xlabel(f'EV: {ev_label} mph')

        # Get subset
        sub_df = exp_outcomes.loc[exp_outcomes['EV'] == ev_label].loc[exp_outcomes['LA'] == la_label]
        if sub_df.shape[0] == 0:
            ax.axis('off')
            continue
        else:
            draw_field(ax)

        # Add wedges
        for k, r in sub_df.iterrows():
            range = (int(r['SA'].split()[0]), int(r['SA'].split()[-1][:-1]))
            ax = draw_wedge(ax, range, val=r['Δ1B'])

fig.suptitle('Δ1B at Coors Field')
fig.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(5, 8, figsize=(18,8))

for i, ev_label in enumerate(ev_labels):
    for j, la_label in enumerate(la_labels):

        # General Plot
        ax = axs[j,i]
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_ylabel(f'LA: {la_label}')
        ax.set_xlabel(f'EV: {ev_label} mph')

        # Get subset
        sub_df = exp_outcomes.loc[exp_outcomes['EV'] == ev_label].loc[exp_outcomes['LA'] == la_label]
        if sub_df.shape[0] == 0:
            ax.axis('off')
            continue
        else:
            draw_field(ax)

        # Add wedges
        for k, r in sub_df.iterrows():
            range = (int(r['SA'].split()[0]), int(r['SA'].split()[-1][:-1]))
            ax = draw_wedge(ax, range, val=r['Δ2B'])

fig.suptitle('Δ2B at Coors Field')
fig.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(5, 8, figsize=(18,8))

for i, ev_label in enumerate(ev_labels):
    for j, la_label in enumerate(la_labels):

        # General Plot
        ax = axs[j,i]
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_ylabel(f'LA: {la_label}')
        ax.set_xlabel(f'EV: {ev_label} mph')

        # Get subset
        sub_df = exp_outcomes.loc[exp_outcomes['EV'] == ev_label].loc[exp_outcomes['LA'] == la_label]
        if sub_df.shape[0] == 0:
            ax.axis('off')
            continue
        else:
            draw_field(ax)

        # Add wedges
        for k, r in sub_df.iterrows():
            range = (int(r['SA'].split()[0]), int(r['SA'].split()[-1][:-1]))
            ax = draw_wedge(ax, range, val=r['Δ3B'])

fig.suptitle('Δ3B at Coors Field')
fig.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(5, 8, figsize=(18,8))

for i, ev_label in enumerate(ev_labels):
    for j, la_label in enumerate(la_labels):

        # General Plot
        ax = axs[j,i]
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_ylabel(f'LA: {la_label}')
        ax.set_xlabel(f'EV: {ev_label} mph')

        # Get subset
        sub_df = exp_outcomes.loc[exp_outcomes['EV'] == ev_label].loc[exp_outcomes['LA'] == la_label]
        if sub_df.shape[0] == 0:
            ax.axis('off')
            continue
        else:
            draw_field(ax)

        # Add wedges
        for k, r in sub_df.iterrows():
            range = (int(r['SA'].split()[0]), int(r['SA'].split()[-1][:-1]))
            ax = draw_wedge(ax, range, val=r['ΔHR'])
            
fig.suptitle('ΔHR at Coors Field')
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Other stadiums

# %%
# Build expected outcomes table
HOME_TEAM = 'SEA'

exp_outcomes = pd.DataFrame(columns=['EV', 'LA', 'SA', 'ΔHR', 'Δ3B', 'Δ2B', 'Δ1B', 'ΔOut', 'Bases_nHome', 'Bases_Home', 'n_Home'])

# Check for valid events
valid_events = [
    'home_run', 'triple', 'double', 'single',
    'field_out', 'sac_fly', 'force_out',
    'double_play', 'grounded_into_double_play',
    'fielders_choice_out', 'fielders_choice',
    'triple_play', 'sac_fly_double_play'
]
df = df.loc[df['events'].isin(valid_events)]

# Iterate through bin type combinations
for ev_bin, la_bin, sa_bin in itertools.product(ev_labels, la_labels, sa_labels):

    # Filter by bin types
    bin_df = df.loc[df['launch_speed_bin'] == ev_bin]
    bin_df = bin_df.loc[bin_df['launch_angle_bin'] == la_bin]
    bin_df = bin_df.loc[bin_df['spray_angle_bin'] == sa_bin]

    # Split by location
    c_bin_df = bin_df.loc[bin_df['home_team'] == HOME_TEAM]
    nc_bin_df = bin_df.loc[bin_df['home_team'] != HOME_TEAM]

    # Iterate through outcomes and compute deltas for hits
    nc = []
    c = []
    deltas = []
    for event in ['home_run', 'triple', 'double', 'single', 'out']:

        # Get event occurance
        if event == 'out':
            nc_n_event = nc_bin_df.loc[nc_bin_df['events'].isin(['field_out', 'sac_fly', 'force_out', 'double_play', 'grounded_into_double_play', 'fielders_choice_out', 'fielders_choice', 'triple_play', 'sac_fly_double_play'])].shape[0]
            c_n_event = c_bin_df.loc[c_bin_df['events'].isin(['field_out', 'sac_fly', 'force_out', 'double_play', 'grounded_into_double_play', 'fielders_choice_out', 'fielders_choice', 'triple_play', 'sac_fly_double_play'])].shape[0]
        else:
            nc_n_event = nc_bin_df.loc[nc_bin_df['events'] == event].shape[0]
            c_n_event = c_bin_df.loc[c_bin_df['events'] == event].shape[0]

        # Convert to probabilities
        try:
            nc_p_event = nc_n_event / nc_bin_df.shape[0]
            c_p_event = c_n_event / c_bin_df.shape[0]
        except ZeroDivisionError:
            deltas.append(np.nan)
            nc.append(np.nan)
            c.append(np.nan)
            continue

        # Compute delta probabilities
        d_p_event = c_p_event - nc_p_event
        deltas.append(d_p_event)
        nc.append(nc_p_event)
        c.append(c_p_event)

    nc_bases = 4 * nc[0] + 3 * nc[1] + 2 * nc[2] + nc[1]
    c_bases = 4 * c[0] + 3 * c[1] + 2 * c[2] + c[1]
    exp_outcomes.loc[exp_outcomes.shape[0]] = [ev_bin, la_bin, sa_bin]  + deltas + [nc_bases, c_bases] + [c_bin_df.shape[0]]

# Drop NA
exp_outcomes.dropna(inplace=True)

# Drop anywhere n_Coors < 50
exp_outcomes = exp_outcomes.loc[exp_outcomes['n_Home'] >= 50]

# Add delta bases
d_bases = 4 * exp_outcomes['ΔHR'] + 3 * exp_outcomes['Δ3B'] + 2 * exp_outcomes['Δ2B'] + exp_outcomes['Δ1B']
exp_outcomes.insert(10, 'ΔBases', d_bases)

# Round 
exp_outcomes = exp_outcomes.round(2)

# %%
fig, axs = plt.subplots(5, 8, figsize=(18,8))

for i, ev_label in enumerate(ev_labels):
    for j, la_label in enumerate(la_labels):

        # General Plot
        ax = axs[j,i]
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_ylabel(f'LA: {la_label}')
        ax.set_xlabel(f'EV: {ev_label} mph')

        # Get subset
        sub_df = exp_outcomes.loc[exp_outcomes['EV'] == ev_label].loc[exp_outcomes['LA'] == la_label]
        if sub_df.shape[0] == 0:
            ax.axis('off')
            continue
        else:
            draw_field(ax)

        # Add wedges
        for k, r in sub_df.iterrows():
            range = (int(r['SA'].split()[0]), int(r['SA'].split()[-1][:-1]))
            ax = draw_wedge(ax, range, val=r['ΔBases'], norm_factor=max(np.abs(exp_outcomes['ΔBases']).max(), 1))

fig.tight_layout()
plt.show()
