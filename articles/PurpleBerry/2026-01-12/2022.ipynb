# %%
import os, io
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pybaseball import *
import requests
from bs4 import BeautifulSoup
# Out:
# /home/dcooper/anaconda3/envs/rockies/lib/python3.13/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
# Get 2025 game logs
data = team_game_logs(2022, 'COL')
data.tail()
# Out:
# /home/dcooper/rockies/pybaseball/pybaseball/team_game_logs.py:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data = pd.read_html(str(table))[0]
#      Gtm        Date Home  Opp Score: Rslt Score: RS Score: RA Score: Inn  \
# 157  158  2022-10-01    @  LAD           L         4         6          9
# 158  159  2022-10-02    @  LAD           W         4         1          9
# 159  160  2022-10-03    @  LAD           W         2         1          9
# 160  161  2022-10-04    @  LAD           W         5         2          9
# 161  162  2022-10-05    @  LAD           L         1         6          9
#
#     Batting Stats: PA Batting Stats: AB  ... Batting Stats: SH  \
# 157                36                32  ...                 0
# 158                38                35  ...                 1
# 159                37                36  ...                 0
# 160                38                37  ...                 0
# 161                33                29  ...                 0
#
#     Batting Stats: SF Batting Stats: ROE Batting Stats: IBB  \
# 157                 0                  0                  0
# 158                 0                  1                  0
# 159                 0                  0                  0
# 160                 0                  1                  0
# 161                 0                  0                  0
#
#     Batting Stats: BAbip Batting Stats: LOB Batting Stats: #  \
# 157                 .261                  5               10
# 158                 .429                  7                9
# 159                 .360                  8                9
# 160                 .261                  6               10
# 161                 .091                  5                9
#
#     Opp Starter: Player Opp Starter: T Opp Starter: GmSc
# 157       Michael Grove              R                40
# 158      Tyler Anderson              L                57
# 159       Tony Gonsolin              R                49
# 160         Julio Urías              L                54
# 161     Clayton Kershaw              L                69
#
# [5 rows x 37 columns]

# %%
def get_pitcher_FIPminus(last, first, season=2022):
    # Get player id
    if last == 'King' and first == 'Michael':
        playerid = 19853
    elif last == 'Knack' and first == 'Landon':
        playerid = 27487
    elif last == 'Lord' and first == 'Brad':
        playerid = 31972
    elif last == 'Jobe' and first == 'Jackson':
        playerid = 30203
    elif last == 'Montero' and first == 'Keider':
        playerid = 22630
    elif last == 'Leiter' and first == 'Jack':
        playerid = 30146
    elif last == 'Warren' and first == 'Will':
        playerid = 30182
    elif last == 'Horton' and first == 'Cade':
        playerid = 31872
    elif last == 'Boyd' and first == 'Matthew':
        playerid = 15440
    elif last == 'Alcantara' and first == 'Sandy':
        playerid = 18684
    elif last == 'Holmes' and first == 'Grant':
        playerid = 16944
    elif last == 'Parker' and first == 'Mitchell' and season == 2024:
        return 94.0
    elif last == 'Parker' and first == 'Mitchell':
        playerid = 27636
    # elif last == 'Dreyer' and first == 'Jack':
        playerid = 30249
    elif last == 'Patrick' and first == 'Chad':
        playerid = 30113
    elif last == 'Gordon' and first == 'Colton':
        playerid = 31312
    elif last == 'Cannon' and first == 'Jonathan':
        playerid = 31730
    elif last == 'Smith' and first == 'Shane':
        playerid = 31687
    elif last == 'Fitts' and first == 'Richard':
        playerid = 30160
    elif last == 'Burns' and first == 'Chase':
        playerid = 35333
    elif last == 'Martinez' and first == 'Nick' and season == 2022:
        return 111.0
    elif last == 'Martinez' and first == 'Nick' and season == 2023:
        return 90.0
    elif last == 'Martinez' and first == 'Nick':
        playerid = 30146
    elif last == 'McGreevy' and first == 'Michael':
        playerid = 29869
    elif last == 'Sugano' and first == 'Tomoyuki':
        playerid = 35321
    elif last == 'Skenes' and first == 'Paul':
        playerid = 33677
    elif last == 'Ohtani' and first == 'Shohei' and season == 2025:
        return 46.0
    elif last == 'Ashcraft' and first == 'Braxton':
        playerid = 23793
    elif last == 'Burrows' and first == 'Mike':
        playerid = 24728
    elif last == 'Farris' and first == 'Mitch':
        playerid = 33628
    elif last == 'Dana' and first == 'Caden':
        playerid = 31508
    elif last == 'Castillo' and first == 'Luis':
        playerid = 15689
    elif last == 'McDonald' and first == 'Trevor':
        playerid = 26448
    elif last == 'Rodríguez' and first == 'Yariel':
        playerid = 33838
    elif last == 'Muñoz' and first == 'Roddery':
        playerid = 25311
    elif last == 'Black' and first == 'Mason':
        playerid = 30171
    elif last == 'Herz' and first == 'DJ':
        playerid = 26389
    elif last == 'Arrighetti' and first == 'Spencer':
        playerid = 29921
    elif last == 'Thorpe' and first == 'Drew':
        playerid = 31967
    elif last == 'Myers' and first == 'Tobias':
        playerid = 22191
    elif last == 'Scott' and first == 'Christian':
        playerid = 30107
    elif last == 'Schwellenbach' and first == 'Spencer':
        playerid = 31846
    elif last == 'Bellozo' and first == 'Valente':
        playerid = 23899
    elif last == 'Morton' and first == 'Charlie':
        playerid = 4676
    elif last == 'Lyles' and first == 'Jordan':
        playerid = 7593
    elif last == 'France' and first == 'J.P.':
        playerid = 21212
    elif last == 'Medina' and first == 'Luis':
        playerid = 21649
    elif last == 'Jin' and first == 'Hyun':
        playerid = 14444
    elif last == 'Leiter' and first == 'Mark':
        playerid = 15551
    elif last == 'Leiter' and first == 'Jack':
        playerid = 30146
    elif last == 'Leiter' and first == 'Jack':
        playerid = 30146
    else:
        playerid = playerid_lookup(last, first, ignore_accents=True)['key_fangraphs'][0]
    print(last, first, playerid)
    
    URL = 'https://www.fangraphs.com/players/{}-{}/{}/stats/pitching'
    session = requests.session()
    
    # Get request
    content = session.get(URL.format(last, first, playerid)).content
    soup = BeautifulSoup(content)
    
    # Get 'Advanced' Table
    tables = soup.find_all('table')
    for i, table in enumerate(tables):
        if table.get_text(strip=True)[:300].startswith('SeasonTeamLevelK/9K/9'):
            df = pd.read_html(io.StringIO(str(table)))[0]
            break
    
    # Get FIP-
    FIPminus = df.loc[df['Season'] == str(season)].loc[df['Level'] == 'MLB']['FIP-FIP- - FIP adjusted for park and league where 100 is average and lower is better'].to_numpy()[0]
    
    return FIPminus


data['Opp Starter: FIP-'] = np.zeros(data.shape[0])
for i, r in data.iterrows():
    # if not r['Date'].startswith('2022-10'):
    #     continue

    opp_pitcher = r['Opp Starter: Player']
    try:
        first, last = opp_pitcher.split()
    except:
        first, last, _ = opp_pitcher.split()
    print(r['Date'], last, first)
    data.loc[i, 'Opp Starter: FIP-'] = get_pitcher_FIPminus(last, first)

data['Opp Starter: FIP-']
# Out:
# 2022-04-08 Buehler Walker
# Gathering player lookup table. This may take a moment.
# Buehler Walker 19374
# 2022-04-09 Gonsolin Tony
# Gonsolin Tony 19388
# 2022-04-10 Urías Julio
# Urías Julio 14765
# 2022-04-11 Hearn Taylor
# Hearn Taylor 18325
# 2022-04-12 Pérez Martín
# Pérez Martín 6902
# 2022-04-14 Steele Justin
# Steele Justin 17312
# 2022-04-15 Stroman Marcus
# Stroman Marcus 13431
# 2022-04-16 Leiter Mark
# Leiter Mark 15551
# 2022-04-17 Smyly Drew
# Smyly Drew 11760
# 2022-04-18 Nola Aaron
# Nola Aaron 16149
# 2022-04-19 Gibson Kyle
# Gibson Kyle 10123
# 2022-04-20 Eflin Zach
# Eflin Zach 13774
# 2022-04-23 (1) Skubal Tarik
# Skubal Tarik 22267
# 2022-04-23 (2) Brieske Beau
# Brieske Beau 26079
# 2022-04-24 Alexander Tyler
# Alexander Tyler 17735
# 2022-04-25 Gibson Kyle
# Gibson Kyle 10123
# 2022-04-26 Eflin Zach
# Eflin Zach 13774
# 2022-04-27 Suárez Ranger
# Suárez Ranger 17277
# 2022-04-28 Wheeler Zack
# Wheeler Zack 10310
# 2022-04-29 Greene Hunter
# Greene Hunter 22182
# 2022-04-30 Overton Connor
# Overton Connor 18376
# 2022-05-01 Sanmartin Reiver
# Sanmartin Reiver 19754
# 2022-05-03 Fedde Erick
# Fedde Erick 17425
# 2022-05-04 Corbin Patrick
# Corbin Patrick 9323
# 2022-05-05 Sanchez Aaron
# Sanchez Aaron 11490
# 2022-05-06 Kelly Merrill
# Kelly Merrill 11156
# 2022-05-07 Davies Zach
# Davies Zach 13183
# 2022-05-08 Gallen Zac
# Gallen Zac 19291
# 2022-05-09 Rodón Carlos
# Rodón Carlos 16137
# 2022-05-10 Wood Alex
# Wood Alex 13781
# 2022-05-11 Cobb Alex
# Cobb Alex 6562
# 2022-05-13 Greinke Zack
# Greinke Zack 1943
# 2022-05-14 Hernández Carlos
# Hernández Carlos 22713
# 2022-05-15 Lynch Daniel
# Lynch Daniel 21537
# 2022-05-16 Wood Alex
# Wood Alex 13781
# 2022-05-17 Cobb Alex
# Cobb Alex 6562
# 2022-05-18 Webb Logan
# Webb Logan 17995
# 2022-05-21 (1) Carrasco Carlos
# Carrasco Carlos 6632
# 2022-05-21 (2) Williams Trevor
# Williams Trevor 16977
# 2022-05-22 Walker Taijuan
# Walker Taijuan 11836
# 2022-05-23 Brubaker JT
# Brubaker JT 17578
# 2022-05-24 Contreras Roansy
# Contreras Roansy 22810
# 2022-05-25 Thompson Zach
# Thompson Zach 16094
# 2022-05-26 Corbin Patrick
# Corbin Patrick 9323
# 2022-05-28 (1) Sanchez Aaron
# Sanchez Aaron 11490
# 2022-05-28 (2) Adon Joan
# Adon Joan 22925
# 2022-05-29 Gray Josiah
# Gray Josiah 24580
# 2022-05-30 López Pablo
# López Pablo 17085
# 2022-06-01 (1) Cabrera Edward
# Cabrera Edward 21690
# 2022-06-01 (2) Rogers Trevor
# Rogers Trevor 22286
# 2022-06-02 Anderson Ian
# Anderson Ian 19951
# 2022-06-03 Fried Max
# Fried Max 13743
# 2022-06-04 Strider Spencer
# Strider Spencer 27498
# 2022-06-05 Morton Charlie
# Morton Charlie 4676
# 2022-06-07 Rodón Carlos
# Rodón Carlos 16137
# 2022-06-08 Wood Alex
# Wood Alex 13781
# 2022-06-09 Webb Logan
# Webb Logan 17995
# 2022-06-10 Musgrove Joe
# Musgrove Joe 12970
# 2022-06-11 (1) Martinez Nick
# 2022-06-11 (2) Gore MacKenzie
# Gore MacKenzie 22201
# 2022-06-12 Snell Blake
# Snell Blake 13543
# 2022-06-14 Bieber Shane
# Bieber Shane 19427
# 2022-06-15 Pilkington Konnor
# Pilkington Konnor 21453
# 2022-06-16 McKenzie Triston
# McKenzie Triston 18000
# 2022-06-17 Gore MacKenzie
# Gore MacKenzie 22201
# 2022-06-18 Martinez Nick
# 2022-06-19 Snell Blake
# Snell Blake 13543
# 2022-06-21 Castano Daniel
# Castano Daniel 19805
# 2022-06-22 López Pablo
# López Pablo 17085
# 2022-06-23 Garrett Braxton
# Garrett Braxton 21844
# 2022-06-24 Bundy Dylan
# Bundy Dylan 12917
# 2022-06-25 Archer Chris
# Archer Chris 6345
# 2022-06-26 Ryan Joe
# Ryan Joe 21390
# 2022-06-27 Anderson Tyler
# Anderson Tyler 12880
# 2022-06-28 Kershaw Clayton
# Kershaw Clayton 2036
# 2022-06-29 Urías Julio
# Urías Julio 14765
# 2022-07-01 Kelly Merrill
# Kelly Merrill 11156
# 2022-07-02 Keuchel Dallas
# Keuchel Dallas 9434
# 2022-07-03 Gallen Zac
# Gallen Zac 19291
# 2022-07-04 Urías Julio
# Urías Julio 14765
# 2022-07-05 Pepiot Ryan
# Pepiot Ryan 26221
# 2022-07-06 White Mitch
# White Mitch 19225
# 2022-07-07 Keuchel Dallas
# Keuchel Dallas 9434
# 2022-07-08 Gallen Zac
# Gallen Zac 19291
# 2022-07-09 Bumgarner Madison
# Bumgarner Madison 5524
# 2022-07-10 Gilbert Tyler
# Gilbert Tyler 17964
# 2022-07-11 Manaea Sean
# Manaea Sean 15873
# 2022-07-12 Clevinger Mike
# Clevinger Mike 12808
# 2022-07-13 Musgrove Joe
# Musgrove Joe 12970
# 2022-07-14 Snell Blake
# Snell Blake 13543
# 2022-07-15 Quintana Jose
# Quintana Jose 11423
# 2022-07-16 Keller Mitch
# Keller Mitch 17594
# 2022-07-17 Wilson Bryse
# Wilson Bryse 19990
# 2022-07-22 Burnes Corbin
# Burnes Corbin 19361
# 2022-07-23 Woodruff Brandon
# Woodruff Brandon 16162
# 2022-07-24 Lauer Eric
# Lauer Eric 19316
# 2022-07-25 Ashby Aaron
# Ashby Aaron 23550
# 2022-07-26 Kopech Michael
# Kopech Michael 17282
# 2022-07-27 Giolito Lucas
# Giolito Lucas 15474
# 2022-07-28 Anderson Tyler
# Anderson Tyler 12880
# 2022-07-29 Urías Julio
# Urías Julio 14765
# 2022-07-30 Kershaw Clayton
# Kershaw Clayton 2036
# 2022-07-31 Gonsolin Tony
# Gonsolin Tony 19388
# 2022-08-01 Clevinger Mike
# Clevinger Mike 12808
# 2022-08-02 (1) Darvish Yu
# Darvish Yu 13074
# 2022-08-02 (2) Knehr Reiss
# Knehr Reiss 21541
# 2022-08-03 Snell Blake
# Snell Blake 13543
# 2022-08-04 Musgrove Joe
# Musgrove Joe 12970
# 2022-08-05 Bumgarner Madison
# Bumgarner Madison 5524
# 2022-08-06 Kelly Merrill
# Kelly Merrill 11156
# 2022-08-07 Davies Zach
# Davies Zach 13183
# 2022-08-09 Mikolas Miles
# Mikolas Miles 9803
# 2022-08-10 Quintana Jose
# Quintana Jose 11423
# 2022-08-11 Hudson Dakota
# Hudson Dakota 19206
# 2022-08-12 Davies Zach
# Davies Zach 13183
# 2022-08-13 Gallen Zac
# Gallen Zac 19291
# 2022-08-14 Henry Tommy
# Henry Tommy 26285
# 2022-08-16 Quintana Jose
# Quintana Jose 11423
# 2022-08-17 Montgomery Jordan
# Montgomery Jordan 16511
# 2022-08-18 Wainwright Adam
# Wainwright Adam 2233
# 2022-08-19 Wood Alex
# Wood Alex 13781
# 2022-08-20 Cobb Alex
# Cobb Alex 6562
# 2022-08-21 Junis Jakob
# Junis Jakob 13619
# 2022-08-23 Dunning Dane
# Dunning Dane 19409
# 2022-08-24 Pérez Martín
# Pérez Martín 6902
# 2022-08-25 deGrom Jacob
# deGrom Jacob 10954
# 2022-08-26 Bassitt Chris
# Bassitt Chris 12304
# 2022-08-27 Peterson David
# Peterson David 20302
# 2022-08-28 Scherzer Max
# Scherzer Max 3137
# 2022-08-30 Fried Max
# Fried Max 13743
# 2022-08-31 Wright Kyle
# Wright Kyle 19665
# 2022-09-01 Strider Spencer
# Strider Spencer 27498
# 2022-09-02 Cessa Luis
# Cessa Luis 13345
# 2022-09-04 (1) Lodolo Nick
# Lodolo Nick 26378
# 2022-09-04 (2) Anderson Chase
# Anderson Chase 6895
# 2022-09-05 Houser Adrian
# Houser Adrian 12718
# 2022-09-06 Woodruff Brandon
# Woodruff Brandon 16162
# 2022-09-07 Lauer Eric
# Lauer Eric 19316
# 2022-09-09 Davies Zach
# Davies Zach 13183
# 2022-09-10 Bumgarner Madison
# Bumgarner Madison 5524
# 2022-09-11 Gallen Zac
# Gallen Zac 19291
# 2022-09-13 Kopech Michael
# Kopech Michael 17282
# 2022-09-14 Cease Dylan
# Cease Dylan 18525
# 2022-09-16 Stroman Marcus
# Stroman Marcus 13431
# 2022-09-17 Wesneski Hayden
# Wesneski Hayden 27581
# 2022-09-18 Assad Javier
# Assad Javier 21741
# 2022-09-19 Junis Jakob
# Junis Jakob 13619
# 2022-09-20 Brebbia John
# Brebbia John 12777
# 2022-09-21 Webb Logan
# Webb Logan 17995
# 2022-09-22 Brebbia John
# Brebbia John 12777
# 2022-09-23 Manaea Sean
# Manaea Sean 15873
# 2022-09-24 Darvish Yu
# Darvish Yu 13074
# 2022-09-25 Clevinger Mike
# Clevinger Mike 12808
# 2022-09-27 Webb Logan
# Webb Logan 17995
# 2022-09-28 Brebbia John
# Brebbia John 12777
# 2022-09-29 Rodón Carlos
# Rodón Carlos 16137
# 2022-09-30 Kershaw Clayton
# Kershaw Clayton 2036
# 2022-10-01 Grove Michael
# Grove Michael 23221
# 2022-10-02 Anderson Tyler
# Anderson Tyler 12880
# 2022-10-03 Gonsolin Tony
# Gonsolin Tony 19388
# 2022-10-04 Urías Julio
# Urías Julio 14765
# 2022-10-05 Kershaw Clayton
# Kershaw Clayton 2036
# 0       94.0
# 1       81.0
# 2       92.0
# 3       99.0
# 4       81.0
#        ...
# 157    127.0
# 158     82.0
# 159     81.0
# 160     92.0
# 161     64.0
# Name: Opp Starter: FIP-, Length: 162, dtype: float64

# %%
FIPminus = data['Opp Starter: FIP-'].to_numpy()
FIPminus
# Out:
# array([ 94.,  81.,  92.,  99.,  81.,  82.,  96., 110., 108.,  64., 105.,
#         87.,  76., 128., 129., 105.,  87.,  95.,  71., 103.,  86., 113.,
#        128., 120., 112.,  95., 125.,  79.,  59.,  98.,  73., 102., 132.,
#        118.,  98.,  73.,  79.,  89.,  98.,  92.,  98., 109., 122., 120.,
#        112., 127., 145.,  93., 115., 109., 109.,  70.,  48., 109.,  59.,
#         98.,  79.,  91., 111., 104.,  71.,  73., 116.,  92., 104., 111.,
#         71., 118.,  93.,  89., 119., 114., 101.,  82.,  64.,  92.,  95.,
#        138.,  79.,  92., 133.,  97., 138.,  79., 125., 153., 114., 125.,
#         91.,  71.,  76.,  97., 126.,  78.,  77., 112., 101., 110., 100.,
#         82.,  92.,  64.,  81., 125.,  84., 110.,  71.,  91., 125.,  95.,
#        125.,  99.,  76., 110., 125.,  79., 151.,  76.,  90.,  93.,  98.,
#         73.,  95., 111.,  81.,  54.,  92.,  92.,  66.,  70.,  92.,  48.,
#        118.,  92., 119., 105.,  77., 112., 125., 125.,  79., 110.,  76.,
#         96.,  82., 115.,  95.,  87.,  79.,  87., 114.,  84., 125.,  79.,
#         87.,  59.,  64., 127.,  82.,  81.,  92.,  64.])

# %%
100/FIPminus
# Out:
# array([1.06382979, 1.2345679 , 1.08695652, 1.01010101, 1.2345679 ,
#        1.2195122 , 1.04166667, 0.90909091, 0.92592593, 1.5625    ,
#        0.95238095, 1.14942529, 1.31578947, 0.78125   , 0.7751938 ,
#        0.95238095, 1.14942529, 1.05263158, 1.4084507 , 0.97087379,
#        1.1627907 , 0.88495575, 0.78125   , 0.83333333, 0.89285714,
#        1.05263158, 0.8       , 1.26582278, 1.69491525, 1.02040816,
#        1.36986301, 0.98039216, 0.75757576, 0.84745763, 1.02040816,
#        1.36986301, 1.26582278, 1.12359551, 1.02040816, 1.08695652,
#        1.02040816, 0.91743119, 0.81967213, 0.83333333, 0.89285714,
#        0.78740157, 0.68965517, 1.07526882, 0.86956522, 0.91743119,
#        0.91743119, 1.42857143, 2.08333333, 0.91743119, 1.69491525,
#        1.02040816, 1.26582278, 1.0989011 , 0.9009009 , 0.96153846,
#        1.4084507 , 1.36986301, 0.86206897, 1.08695652, 0.96153846,
#        0.9009009 , 1.4084507 , 0.84745763, 1.07526882, 1.12359551,
#        0.84033613, 0.87719298, 0.99009901, 1.2195122 , 1.5625    ,
#        1.08695652, 1.05263158, 0.72463768, 1.26582278, 1.08695652,
#        0.7518797 , 1.03092784, 0.72463768, 1.26582278, 0.8       ,
#        0.65359477, 0.87719298, 0.8       , 1.0989011 , 1.4084507 ,
#        1.31578947, 1.03092784, 0.79365079, 1.28205128, 1.2987013 ,
#        0.89285714, 0.99009901, 0.90909091, 1.        , 1.2195122 ,
#        1.08695652, 1.5625    , 1.2345679 , 0.8       , 1.19047619,
#        0.90909091, 1.4084507 , 1.0989011 , 0.8       , 1.05263158,
#        0.8       , 1.01010101, 1.31578947, 0.90909091, 0.8       ,
#        1.26582278, 0.66225166, 1.31578947, 1.11111111, 1.07526882,
#        1.02040816, 1.36986301, 1.05263158, 0.9009009 , 1.2345679 ,
#        1.85185185, 1.08695652, 1.08695652, 1.51515152, 1.42857143,
#        1.08695652, 2.08333333, 0.84745763, 1.08695652, 0.84033613,
#        0.95238095, 1.2987013 , 0.89285714, 0.8       , 0.8       ,
#        1.26582278, 0.90909091, 1.31578947, 1.04166667, 1.2195122 ,
#        0.86956522, 1.05263158, 1.14942529, 1.26582278, 1.14942529,
#        0.87719298, 1.19047619, 0.8       , 1.26582278, 1.14942529,
#        1.69491525, 1.5625    , 0.78740157, 1.2195122 , 1.2345679 ,
#        1.08695652, 1.5625    ])

# %%
# Weights
weights = 100 / FIPminus
weights_sum = weights.sum()

# %%
# Method to find games after home/away switch
away_inds = [[] for i in range(11)]
home_inds = [[] for i in range(11)]
home_count = 0
away_count = 0
last = None
for i, r in data.iterrows():
    loc = r['Home']
    if loc == '@':
        if last in ['Home', None]:
            away_count = 1
            home_count = 0
        else:
            away_count += 1
        away_inds[away_count-1].append(i)
        last = 'Away'
    else:
        if last in ['Away', None]:
            home_count = 1
            away_count = 0
        else:
            home_count += 1
        home_inds[home_count-1].append(i)
        last = 'Home'

# %%
# Plot a stat
for col in data.columns:
    if col.startswith('Batting Stats'):
        stat = col
    else:
        continue
    home_stat = np.zeros(6)
    home_stat_err = np.zeros(6)
    away_stat = np.zeros(6)
    away_stat_err = np.zeros(6)
    away_stat[:] = np.nan
    home_stat[:] = np.nan
    away_stat_err[:] = np.nan
    home_stat_err[:] = np.nan 
    for i, (home_inds_i, away_inds_i) in enumerate(zip(home_inds[:6], away_inds[:6])):
        away_data = data.iloc[away_inds_i][stat].to_numpy().astype(float)
        away_data = np.array(away_data * weights[away_inds_i]) # Weight
        away_stat[i] = np.median(away_data)
        away_stat_err[i] = away_data.std() / np.sqrt(away_data.shape[0])
    
        home_data = data.iloc[home_inds_i][stat].to_numpy().astype(float)
        home_data = np.array(home_data * weights[home_inds_i]) # Weight
        home_stat[i] = np.median(home_data)
        home_stat_err[i] = home_data.std() / np.sqrt(home_data.shape[0])
    
    
    plt.plot(np.arange(1, 7), home_stat, label='home', marker='o', color='purple')
    plt.fill_between(np.arange(1, 7), home_stat - home_stat_err, home_stat + home_stat_err, color='purple', alpha=0.2)
    plt.plot(np.arange(1, 7), away_stat, label='away', marker='o', color='silver')
    plt.fill_between(np.arange(1, 7), away_stat - away_stat_err, away_stat + away_stat_err, color='silver', alpha=0.2)

        
    plt.ylabel(stat)
    plt.legend(bbox_to_anchor=(1,1))
    plt.show()

# %%
for col in data.columns:
    print(col)
# Out:
# Gtm
# Date
# Home
# Opp
# Score: Rslt
# Score: RS
# Score: RA
# Score: Inn
# Batting Stats: PA
# Batting Stats: AB
# Batting Stats: R
# Batting Stats: H
# Batting Stats: 2B
# Batting Stats: 3B
# Batting Stats: HR
# Batting Stats: RBI
# Batting Stats: SB
# Batting Stats: CS
# Batting Stats: BB
# Batting Stats: SO
# Batting Stats: BA
# Batting Stats: OBP
# Batting Stats: SLG
# Batting Stats: OPS
# Batting Stats: TB
# Batting Stats: GIDP
# Batting Stats: HBP
# Batting Stats: SH
# Batting Stats: SF
# Batting Stats: ROE
# Batting Stats: IBB
# Batting Stats: BAbip
# Batting Stats: LOB
# Batting Stats: #
# Opp Starter: Player
# Opp Starter: T
# Opp Starter: GmSc
# Opp Starter: FIP-

# %%
# Methods
def get_stat(data, inds, stat, weights=None):
    if weights is None:
        return data.iloc[inds][f'Batting Stats: {stat}'].to_numpy().astype(float).sum()
    else:
        return np.dot(data.iloc[inds][f'Batting Stats: {stat}'].to_numpy().astype(float), weights)


def get_BA(hits, AB):
    return (hits / AB).round(3)

def get_OBP(H, BB, HBP, AB, SF):
    return ((H + BB + HBP) / (AB + BB + HBP + SF)).round(3)

def get_SLG(singles, doubles, triples, home_runs, AB):
    return ((singles + 2*doubles + 3*triples + 4*home_runs) / AB).round(3)

def get_ISO(SLG, BA):
    return (SLG - BA).round(3)

def get_OPS(OBP, SLG):
    return (OBP + SLG).round(3)

def get_wOBA(single, double, triple, home_run, BB, IBB, HBP, AB, SF=0):
    return ((0.691*(BB-IBB) + 0.722*HBP + 0.882*single + 1.252*double + 1.584*triple + 2.037*home_run) / (AB + BB - IBB + SF + HBP)).round(3)

def get_wRAA(wOBA, PA=502, lgwOBA=0.314, wOBA_scale=1.232):
    return (PA * ((wOBA - lgwOBA) / wOBA_scale)).round(1)

def get_day_splits(inds, weights=None):

    # Handle weights
    if weights is None:
        weights = np.repeat(1, 162)
    
    # Iterate through home/away switches
    Runs = np.zeros(6)
    BAs = np.zeros(6)
    OBPs = np.zeros(6)
    SLGs = np.zeros(6)
    ISOs = np.zeros(6)
    OPSs = np.zeros(6)
    wOBAs = np.zeros(6)
    wRAAs = np.zeros(6)
    SOs = np.zeros(6)
    BBs = np.zeros(6)
    for i, (inds_i) in enumerate(zip(inds[:6])):
    
        # Get outcome sums
        PA = get_stat(data, inds_i, 'PA')
        AB = get_stat(data, inds_i, 'AB')
        H = get_stat(data, inds_i, 'H', weights[inds_i])
        doubles = get_stat(data, inds_i, '2B', weights[inds_i])
        triples = get_stat(data, inds_i, '3B', weights[inds_i])
        home_runs = get_stat(data, inds_i, 'HR', weights[inds_i])
        singles = H - doubles - triples - home_runs
        BB = get_stat(data, inds_i, 'BB', weights[inds_i])
        HBP = get_stat(data, inds_i, 'HBP', weights[inds_i])
        IBB = get_stat(data, inds_i, 'IBB', weights[inds_i])
        SF = get_stat(data, inds_i, 'SF', weights[inds_i])
        Runs[i] = get_stat(data, inds_i, 'R', weights[inds_i]) / len(inds_i[0])
        SO = get_stat(data, inds_i, 'SO', weights[inds_i])
    
        # Get stats
        BAs[i] = get_BA(H, AB)
        OBPs[i] = get_OBP(H, BB, HBP, AB, SF)
        SLGs[i] = get_SLG(singles, doubles, triples, home_runs, AB)
        ISOs[i] = get_ISO(SLGs[i], BAs[i])
        OPSs[i] = get_OPS(OBPs[i], SLGs[i])
        wOBAs[i] = get_wOBA(singles, doubles, triples, home_runs, BB, IBB, HBP, AB, SF)
        wRAAs[i] = get_wRAA(wOBAs[i], PA=PA)
        SOs[i] = SO / PA
        BBs[i] = BB / PA


    return Runs, BAs, OBPs, SLGs, ISOs, OPSs, wOBAs, wRAAs, SOs, BBs

# %%
home_splits = get_day_splits(home_inds, weights=weights)
away_splits = get_day_splits(away_inds, weights=weights)
# home_splits = get_day_splits(home_inds)
# away_splits = get_day_splits(away_inds)

# %%
from matplotlib.ticker import FormatStrFormatter

stat_names = ['R', 'BA', 'OPB', 'SLG', 'ISO', 'OPS', 'wOBA', 'wRAA', 'SO', 'BB']
for home_stat, away_stat, stat in zip(home_splits, away_splits, stat_names):

    fig, ax = plt.subplots()
    ax.plot(np.arange(1, 7), home_stat, label='home', marker='o', color='purple')
    # plt.fill_between(np.arange(1, 7), home_stat - home_stat_err, home_stat + home_stat_err, color='purple', alpha=0.2)
    ax.plot(np.arange(1, 7), away_stat, label='away', marker='o', color='silver')
    # plt.fill_between(np.arange(1, 7), away_stat - away_stat_err, away_stat + away_stat_err, color='silver', alpha=0.2)

        
    ax.set_ylabel(stat)
    ax.yaxis.set_major_formatter(FormatStrFormatter('%.3f'))
    ax.legend(bbox_to_anchor=(1,1))
    plt.show()
