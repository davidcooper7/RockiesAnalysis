# %%
import os, io
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pybaseball import *
import requests
from bs4 import BeautifulSoup

# %%
# Get 2025 game logs
data = team_game_logs(2025, 'COL')
data.tail()
# Out:
# /home/dcooper/rockies/pybaseball/pybaseball/team_game_logs.py:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data = pd.read_html(str(table))[0]
#      Gtm        Date Home  Opp Score: Rslt Score: RS Score: RA Score: Inn  \
# 157  158  2025-09-24    @  SEA           L         2         9          9
# 158  159  2025-09-25    @  SEA           L         2         6          9
# 159  160  2025-09-26    @  SFG           L         3         6          9
# 160  161  2025-09-27    @  SFG           L         3         4          9
# 161  162  2025-09-28    @  SFG           L         0         4          9
#
#     Batting Stats: PA Batting Stats: AB  ... Batting Stats: SH  \
# 157                30                29  ...                 0
# 158                39                36  ...                 0
# 159                33                33  ...                 0
# 160                37                33  ...                 0
# 161                32                30  ...                 0
#
#     Batting Stats: SF Batting Stats: ROE Batting Stats: IBB  \
# 157                 0                  0                  0
# 158                 0                  0                  0
# 159                 0                  1                  0
# 160                 0                  0                  0
# 161                 0                  0                  0
#
#     Batting Stats: BAbip Batting Stats: LOB Batting Stats: #  \
# 157                 .059                  1                9
# 158                 .391                 10               10
# 159                 .211                  3                9
# 160                 .182                  7                9
# 161                 .294                  5                9
#
#     Opp Starter: Player Opp Starter: T Opp Starter: GmSc
# 157       Luis Castillo              R                82
# 158     Emerson Hancock              R                65
# 159     Trevor McDonald              R                73
# 160    Justin Verlander              R                60
# 161          Logan Webb              R                70
#
# [5 rows x 37 columns]

# %%
def get_pitcher_FIPminus(last, first, season=2025):
    # Get player id
    if last == 'King' and first == 'Michael':
        playerid = 19853
    elif last == 'Knack' and first == 'Landon':
        playerid = 27487
    elif last == 'Lord' and first == 'Brad':
        playerid = 31972
    elif last == 'Jobe' and first == 'Jackson':
        playerid = 30203
    elif last == 'Montero' and first == 'Keider':
        playerid = 22630
    elif last == 'Leiter' and first == 'Jack':
        playerid = 30146
    elif last == 'Warren' and first == 'Will':
        playerid = 30182
    elif last == 'Horton' and first == 'Cade':
        playerid = 31872
    elif last == 'Boyd' and first == 'Matthew':
        playerid = 15440
    elif last == 'Alcantara' and first == 'Sandy':
        playerid = 18684
    elif last == 'Holmes' and first == 'Grant':
        playerid = 16944
    elif last == 'Parker' and first == 'Mitchell':
        playerid = 27636
    elif last == 'Dreyer' and first == 'Jack':
        playerid = 30249
    elif last == 'Patrick' and first == 'Chad':
        playerid = 30113
    elif last == 'Gordon' and first == 'Colton':
        playerid = 31312
    elif last == 'Cannon' and first == 'Jonathan':
        playerid = 31730
    elif last == 'Smith' and first == 'Shane':
        playerid = 31687
    elif last == 'Fitts' and first == 'Richard':
        playerid = 30160
    elif last == 'Burns' and first == 'Chase':
        playerid = 35333
    elif last == 'Martinez' and first == 'Nick':
        playerid = 30146
    elif last == 'McGreevy' and first == 'Michael':
        playerid = 29869
    elif last == 'Sugano' and first == 'Tomoyuki':
        playerid = 35321
    elif last == 'Skenes' and first == 'Paul':
        playerid = 33677
    elif last == 'Ohtani' and first == 'Shohei':
        return 46.0
    elif last == 'Ashcraft' and first == 'Braxton':
        playerid = 23793
    elif last == 'Burrows' and first == 'Mike':
        playerid = 24728
    elif last == 'Farris' and first == 'Mitch':
        playerid = 33628
    elif last == 'Dana' and first == 'Caden':
        playerid = 31508
    elif last == 'Castillo' and first == 'Luis':
        playerid = 15689
    elif last == 'McDonald' and first == 'Trevor':
        playerid = 26448
    elif last == 'Leiter' and first == 'Jack':
        playerid = 30146
    elif last == 'Leiter' and first == 'Jack':
        playerid = 30146
    elif last == 'Leiter' and first == 'Jack':
        playerid = 30146
    elif last == 'Leiter' and first == 'Jack':
        playerid = 30146
    elif last == 'Leiter' and first == 'Jack':
        playerid = 30146
    elif last == 'Leiter' and first == 'Jack':
        playerid = 30146
    elif last == 'Leiter' and first == 'Jack':
        playerid = 30146
    else:
        playerid = playerid_lookup(last, first, ignore_accents=True)['key_fangraphs'][0]
    print(last, first, playerid)
    
    URL = 'https://www.fangraphs.com/players/{}-{}/{}/stats/pitching'
    session = requests.session()
    
    # Get request
    content = session.get(URL.format(last, first, playerid)).content
    soup = BeautifulSoup(content)
    
    # Get 'Advanced' Table
    tables = soup.find_all('table')
    for i, table in enumerate(tables):
        if table.get_text(strip=True)[:300].startswith('SeasonTeamLevelK/9K/9'):
            df = pd.read_html(io.StringIO(str(table)))[0]
            break
    
    # Get FIP-
    FIPminus = df.loc[df['Season'] == str(season)].loc[df['Level'] == 'MLB']['FIP-FIP- - FIP adjusted for park and league where 100 is average and lower is better'].to_numpy()[0]
    
    return FIPminus


data['Opp Starter: FIP-'] = np.zeros(data.shape[0])
for i, r in data.iterrows():
    opp_pitcher = r['Opp Starter: Player']
    first, last = opp_pitcher.split()
    print(r['Date'], last, first)
    data.loc[i, 'Opp Starter: FIP-'] = get_pitcher_FIPminus(last, first)

data['Opp Starter: FIP-']
# Out:
# 2025-03-28 Pepiot Ryan
# Pepiot Ryan 26221
# 2025-03-29 Littell Zack
# Littell Zack 15823
# 2025-03-30 Bradley Taj
# Bradley Taj 22543
# 2025-03-31 Sánchez Cristopher
# Sánchez Cristopher 20778
# 2025-04-02 Wheeler Zack
# Wheeler Zack 10310
# 2025-04-03 Walker Taijuan
# Walker Taijuan 11836
# 2025-04-04 Bido Osvaldo
# Bido Osvaldo 23150
# 2025-04-05 Sears JP
# Sears JP 23429
# 2025-04-06 Estes Joey
# Estes Joey 26257
# 2025-04-08 Peralta Freddy
# Peralta Freddy 18679
# 2025-04-09 Alexander Tyler
# Alexander Tyler 17735
# 2025-04-10 Priester Quinn
# Priester Quinn 25977
# 2025-04-11 Pivetta Nick
# Pivetta Nick 15454
# 2025-04-12 Hart Kyle
# Hart Kyle 19646
# 2025-04-13 King Michael
# King Michael 19853
# 2025-04-14 May Dustin
# May Dustin 19716
# 2025-04-15 Knack Landon
# Knack Landon 27487
# 2025-04-16 Miller Bobby
# Miller Bobby 27483
# 2025-04-19 Gore MacKenzie
# Gore MacKenzie 22201
# 2025-04-20 (1) Irvin Jake
# Irvin Jake 21504
# 2025-04-20 (2) Lord Brad
# Lord Brad 31972
# 2025-04-22 Bubic Kris
# Bubic Kris 21455
# 2025-04-24 (1) Ragans Cole
# Ragans Cole 21846
# 2025-04-24 (2) Lorenzen Michael
# Lorenzen Michael 14843
# 2025-04-25 Abbott Andrew
# Abbott Andrew 29911
# 2025-04-26 Greene Hunter
# Greene Hunter 22182
# 2025-04-27 Lodolo Nick
# 2025-08-29 Horton Cade
# Horton Cade 31872
# 2025-08-30 Assad Javier
# Assad Javier 21741
# 2025-08-31 Boyd Matthew
# Boyd Matthew 15440
# 2025-09-01 Teng Kai-Wei
# Teng Kai-Wei 24282
# 2025-09-02 Webb Logan
# Webb Logan 17995
# 2025-09-03 Ray Robbie
# Ray Robbie 11486
# 2025-09-05 Pivetta Nick
# Pivetta Nick 15454
# 2025-09-06 Vásquez Randy
# Vásquez Randy 24719
# 2025-09-07 Cease Dylan
# Cease Dylan 18525
# 2025-09-08 Glasnow Tyler
# Glasnow Tyler 14374
# 2025-09-09 Sheehan Emmet
# Sheehan Emmet 29839
# 2025-09-10 Snell Blake
# Snell Blake 13543
# 2025-09-11 Vásquez Randy
# Vásquez Randy 24719
# 2025-09-12 Sears JP
# Sears JP 23429
# 2025-09-13 Cease Dylan
# Cease Dylan 18525
# 2025-09-14 Darvish Yu
# Darvish Yu 13074
# 2025-09-16 Pérez Eury
# Pérez Eury 27768
# 2025-09-17 Weathers Ryan
# Weathers Ryan 23796
# 2025-09-18 Alcantara Sandy
# Alcantara Sandy 18684
# 2025-09-19 Farris Mitch
# Farris Mitch 33628
# 2025-09-20 Hendricks Kyle
# Hendricks Kyle 12049
# 2025-09-21 Dana Caden
# Dana Caden 31508
# 2025-09-23 Miller Bryce
# Miller Bryce 29837
# 2025-09-24 Castillo Luis
# Castillo Luis 15689
# 2025-09-25 Hancock Emerson
# Hancock Emerson 27470
# 2025-09-26 McDonald Trevor
# McDonald Trevor 26448
# 2025-09-27 Verlander Justin
# Verlander Justin 8700
# 2025-09-28 Webb Logan
# Webb Logan 17995
# 0      103.0
# 1      114.0
# 2      103.0
# 3       61.0
# 4       72.0
#        ...
# 157     97.0
# 158    127.0
# 159     64.0
# 160     97.0
# 161     66.0
# Name: Opp Starter: FIP-, Length: 162, dtype: float64

# %%
FIPminus = data['Opp Starter: FIP-'].to_numpy()

# %%
FIPminus/100
# Out:
# array([1.03, 1.14, 1.03, 0.61, 0.72, 1.2 , 1.44, 1.24, 2.07, 0.88, 0.86,
#        0.97, 0.85, 1.26, 1.08, 1.15, 1.33, 1.71, 0.9 , 1.35, 1.02, 0.69,
#        0.59, 1.1 , 0.84, 0.76, 0.88, 1.12, 0.96, 0.67, 0.97, 0.99, 1.08,
#        0.66, 1.24, 0.93, 1.18, 1.18, 0.93, 0.85, 0.8 , 0.99, 1.01, 0.99,
#        1.13, 0.93, 0.61, 0.69, 1.2 , 0.77, 0.93, 0.72, 0.95, 1.14, 0.88,
#        0.9 , 0.85, 1.  , 1.  , 1.08, 1.03, 1.24, 1.  , 1.  , 0.84, 0.92,
#        0.99, 1.24, 1.12, 1.11, 1.08, 1.35, 1.02, 1.2 , 0.99, 1.13, 0.93,
#        1.05, 0.67, 0.7 , 0.84, 1.16, 0.97, 0.85, 1.3 , 0.75, 0.96, 0.89,
#        1.2 , 0.95, 1.39, 1.  , 0.99, 0.62, 0.92, 0.99, 1.21, 0.91, 0.89,
#        1.05, 1.27, 1.15, 0.95, 0.67, 1.3 , 1.13, 1.06, 0.85, 1.35, 0.58,
#        0.98, 0.91, 1.1 , 0.8 , 1.13, 1.14, 1.05, 1.24, 0.99, 1.05, 1.14,
#        1.05, 0.94, 1.21, 0.7 , 0.69, 0.46, 0.84, 0.68, 0.97, 0.58, 0.75,
#        0.81, 1.23, 0.88, 1.04, 0.9 , 0.96, 0.66, 0.99, 0.85, 1.18, 0.87,
#        0.88, 0.69, 0.64, 1.18, 1.24, 0.87, 1.17, 0.89, 1.11, 1.03, 1.13,
#        1.09, 1.54, 1.3 , 0.97, 1.27, 0.64, 0.97, 0.66])

# %%
# Method to find games after home/away switch
away_inds = [[] for i in range(11)]
home_inds = [[] for i in range(11)]
home_count = 0
away_count = 0
last = None
for i, r in data.iterrows():
    loc = r['Home']
    if loc == '@':
        if last in ['Home', None]:
            away_count = 1
            home_count = 0
        else:
            away_count += 1
        away_inds[away_count-1].append(i)
        last = 'Away'
    else:
        if last in ['Away', None]:
            home_count = 1
            away_count = 0
        else:
            home_count += 1
        home_inds[home_count-1].append(i)
        last = 'Home'

# %%
# Weights
weights = FIPminus / 100
weights_sum = weights.sum()

# %%
# Plot a stat
for col in data.columns:
    if col.startswith('Batting Stats'):
        stat = col
    else:
        continue
    home_stat = np.zeros(6)
    home_stat_err = np.zeros(6)
    away_stat = np.zeros(6)
    away_stat_err = np.zeros(6)
    away_stat[:] = np.nan
    home_stat[:] = np.nan
    away_stat_err[:] = np.nan
    home_stat_err[:] = np.nan 
    for i, (home_inds_i, away_inds_i) in enumerate(zip(home_inds[:6], away_inds[:6])):
        away_data = data.iloc[away_inds_i][stat].to_numpy().astype(float)
        # away_data = np.array(away_data * weights[away_inds_i]) # Weight
        away_stat[i] = np.median(away_data)
        away_stat_err[i] = away_data.std() / np.sqrt(away_data.shape[0])
    
        home_data = data.iloc[home_inds_i][stat].to_numpy().astype(float)
        # home_data = np.array(home_data * weights[home_inds_i]) # Weight
        home_stat[i] = np.median(home_data)
        home_stat_err[i] = home_data.std() / np.sqrt(home_data.shape[0])
    
    
    plt.plot(np.arange(1, 7), home_stat, label='home', marker='o', color='purple')
    plt.fill_between(np.arange(1, 7), home_stat - home_stat_err, home_stat + home_stat_err, color='purple', alpha=0.2)
    plt.plot(np.arange(1, 7), away_stat, label='away', marker='o', color='silver')
    plt.fill_between(np.arange(1, 7), away_stat - away_stat_err, away_stat + away_stat_err, color='silver', alpha=0.2)

        
    plt.ylabel(stat)
    plt.legend(bbox_to_anchor=(1,1))
    plt.show()

# %%
for col in data.columns:
    print(col)
# Out:
# Gtm
# Date
# Home
# Opp
# Score: Rslt
# Score: RS
# Score: RA
# Score: Inn
# Batting Stats: PA
# Batting Stats: AB
# Batting Stats: R
# Batting Stats: H
# Batting Stats: 2B
# Batting Stats: 3B
# Batting Stats: HR
# Batting Stats: RBI
# Batting Stats: SB
# Batting Stats: CS
# Batting Stats: BB
# Batting Stats: SO
# Batting Stats: BA
# Batting Stats: OBP
# Batting Stats: SLG
# Batting Stats: OPS
# Batting Stats: TB
# Batting Stats: GIDP
# Batting Stats: HBP
# Batting Stats: SH
# Batting Stats: SF
# Batting Stats: ROE
# Batting Stats: IBB
# Batting Stats: BAbip
# Batting Stats: LOB
# Batting Stats: #
# Opp Starter: Player
# Opp Starter: T
# Opp Starter: GmSc
# Opp Starter: FIP-

# %%
# Methods
def get_stat(data, inds, stat):
    return data.iloc[inds][f'Batting Stats: {stat}'].to_numpy().astype(float).sum()

def get_BA(hits, AB):
    return (hits / AB).round(3)

def get_OBP(H, BB, HBP, AB, SF):
    return ((H + BB + HBP) / (AB + BB + HBP + SF)).round(3)

def get_SLG(singles, doubles, triples, home_runs, AB):
    return ((singles + 2*doubles + 3*triples + 4*home_runs) / AB).round(3)

def get_ISO(SLG, BA):
    return (SLG - BA).round(3)

def get_OPS(OBP, SLG):
    return (OBP + SLG).round(3)

def get_wOBA(single, double, triple, home_run, BB, IBB, HBP, AB, SF=0):
    return ((0.691*(BB-IBB) + 0.722*HBP + 0.882*single + 1.252*double + 1.584*triple + 2.037*home_run) / (AB + BB - IBB + SF + HBP)).round(3)

def get_wRAA(wOBA, PA=502, lgwOBA=0.314, wOBA_scale=1.232):
    return (PA * ((wOBA - lgwOBA) / wOBA_scale)).round(1)

def get_day_splits(inds):
    # Iterate through home/away switches
    Runs = np.zeros(6)
    BAs = np.zeros(6)
    OBPs = np.zeros(6)
    SLGs = np.zeros(6)
    ISOs = np.zeros(6)
    OPSs = np.zeros(6)
    wOBAs = np.zeros(6)
    wRAAs = np.zeros(6)
    SOs = np.zeros(6)
    BBs = np.zeros(6)
    for i, (inds_i) in enumerate(zip(inds[:6])):
    
        # Get outcome sums
        PA = get_stat(data, inds_i, 'PA')
        AB = get_stat(data, inds_i, 'AB')
        H = get_stat(data, inds_i, 'H')
        doubles = get_stat(data, inds_i, '2B')
        triples = get_stat(data, inds_i, '3B')
        home_runs = get_stat(data, inds_i, 'HR')
        singles = H - doubles - triples - home_runs
        BB = get_stat(data, inds_i, 'BB')
        HBP = get_stat(data, inds_i, 'HBP')
        IBB = get_stat(data, inds_i, 'IBB')
        SF = get_stat(data, inds_i, 'SF')
        Runs[i] = get_stat(data, inds_i, 'R') / len(inds_i[0])
        SO = get_stat(data, inds_i, 'SO')
    
        # Get stats
        BAs[i] = get_BA(H, AB)
        OBPs[i] = get_OBP(H, BB, HBP, AB, SF)
        SLGs[i] = get_SLG(singles, doubles, triples, home_runs, AB)
        ISOs[i] = get_ISO(SLG, BA)
        OPSs[i] = get_OPS(OBP, SLG)
        wOBAs[i] = get_wOBA(singles, doubles, triples, home_runs, BB, IBB, HBP, AB, SF)
        wRAAs[i] = get_wRAA(wOBA, PA=PA)
        SOs[i] = SO / PA
        BBs[i] = BB / PA

    return Runs, BAs, OBPs, SLGs, ISOs, OPSs, wOBAs, wRAAs, SOs, BBs

# %%
home_splits = get_day_splits(home_inds)
away_splits = get_day_splits(away_inds)

# %%
stat_names = ['R', 'BA', 'OPB', 'SLG', 'ISO', 'OPS', 'wOBA', 'wRAA', 'SO', 'BB']
for home_stat, away_stat, stat in zip(home_splits, away_splits, stat_names):
    plt.plot(np.arange(1, 7), home_stat, label='home', marker='o', color='purple')
    # plt.fill_between(np.arange(1, 7), home_stat - home_stat_err, home_stat + home_stat_err, color='purple', alpha=0.2)
    plt.plot(np.arange(1, 7), away_stat, label='away', marker='o', color='silver')
    # plt.fill_between(np.arange(1, 7), away_stat - away_stat_err, away_stat + away_stat_err, color='silver', alpha=0.2)

        
    plt.ylabel(stat)
    plt.legend(bbox_to_anchor=(1,1))
    plt.show()
